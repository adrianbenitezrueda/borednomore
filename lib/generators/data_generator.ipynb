# %% [markdown]
# # Generate proposal database

# %% [markdown]
# ## Home activities

# %%
import pandas as pd
import random

# Definir estructura de categorías y subcategorías con sus plantillas para actividades en casa
category_templates = {
    'Manualidades': {
        'Pintura y Dibujo': [
            'Crear una pintura al óleo de {tema}',
            'Dibujar un retrato de {persona}',
            'Realizar un boceto de {objeto}',
            'Practicar acuarela con {estilo}',
            'Dibujar cómics sobre {tema}',
            'Pintar con técnica {tecnica}',
            'Ilustrar un cuento sobre {tema}',
            'Crear un mural en {superficie}',
            'Hacer un collage de {materiales}',
            'Diseñar un logotipo para {proyecto}',
            'Pintar mandalas para {objetivo}',
            'Dibujar con carboncillo {tema}',
            'Crear arte abstracto con {herramienta}',
            'Practicar lettering con {estilo}',
            'Hacer ilustraciones digitales de {tema}',
            'Pintar acuarelas de paisajes',
            'Dibujar retratos de mascotas',
            'Crear cómic sobre {aventura}',
            'Diseñar tarjetas de felicitación',
            'Practicar técnicas de sombreado'
        ],
        'Artesanía': [
            'Tejer una bufanda con {material}',
            'Crear joyería con {materiales}',
            'Hacer cerámica con {tecnica}',
            'Construir maquetas de {edificio}',
            'Realizar origami de {figura}',
            'Diseñar ropa con {estilo}',
            'Hacer velas aromáticas de {aroma}',
            'Crear jabón artesanal con {ingredientes}',
            'Bordar un cojín con {diseno}',
            'Tallado en madera de {objeto}',
            'Crear álbum de recortes de {evento}',
            'Hacer macramé para decoración',
            'Confeccionar muñecos de tela',
            'Diseñar accesorios con materiales reciclados',
            'Crear mosaicos con azulejos',
            'Hacer flores de papel',
            'Construir instrumentos caseros',
            'Personalizar zapatos con {diseno}',
            'Crear marcos de fotos artesanales',
            'Hacer máscaras de carnaval'
        ],
        'Escultura': [
            'Modelar una figura de arcilla casera',
            'Tallar una escultura en jabón',
            'Crear una figura con plastilina',
            'Esculpir una forma abstracta en barro',
            'Hacer una escultura de papel maché',
            'Crear una figura de alambre',
            'Modelar una miniatura en plastilina',
            'Hacer una escultura con pasta de sal',
            'Crear un busto en arcilla polimérica',
            'Diseñar una pieza decorativa en arcilla',
            'Crear una escultura reciclada con objetos de casa',
            'Hacer una figura en pasta de modelar',
            'Diseñar una máscara decorativa en papel maché',
            'Crear una figura abstracta con cartón',
            'Esculpir en cera con velas sobrantes',
            'Crear una figura en arcilla autoendurecible',
            'Hacer una escultura de animales con plastilina',
            'Crear una figura geométrica con cartón reciclado',
            'Hacer una pieza decorativa en yeso',
            'Crear una escultura en masa de maicena'
        ],
        'Costura': [
            'Coser una funda para almohada',
            'Reparar una prenda con un parche',
            'Hacer un cojín decorativo',
            'Coser un delantal para la cocina',
            'Crear una bolsa de tela reutilizable',
            'Hacer una funda para un cuaderno',
            'Reparar un pantalón con un dobladillo nuevo',
            'Confeccionar una manta de retazos',
            'Coser una funda para la tableta',
            'Hacer una bufanda sencilla',
            'Crear una funda para gafas',
            'Coser un neceser con cremalleras',
            'Hacer una funda de tela para la silla',
            'Confeccionar un estuche para lápices',
            'Coser una camiseta básica',
            'Hacer una diadema de tela',
            'Reparar agujeros en ropa vieja',
            'Coser un mantel para la mesa',
            'Hacer un bolso de mano',
            'Confeccionar una camiseta personalizada'
        ],
        'Tejido': [
            'Tejer una bufanda básica',
            'Hacer un gorro de lana a crochet',
            'Tejer un chaleco para el invierno',
            'Hacer un cojín con punto',
            'Tejer una manta pequeña',
            'Crear unos mitones tejidos',
            'Hacer una bolsa tejida',
            'Tejer una alfombra pequeña',
            'Crear una diadema tejida',
            'Tejer unos calcetines',
            'Hacer una funda tejida para una taza',
            'Crear un monedero tejido',
            'Tejer una manta para el sofá',
            'Hacer una funda tejida para el móvil',
            'Crear un amigurumi (muñeco tejido)',
            'Tejer una bufanda infinita',
            'Hacer una funda para cojín a crochet',
            'Crear unos guantes de lana tejidos',
            'Tejer una camiseta de verano',
            'Hacer una manta con lana gruesa'
        ],
        'Modelado': [
            'Crear una figura de arcilla casera',
            'Hacer una taza de cerámica casera',
            'Modelar un plato decorativo',
            'Crear una figura de animales con plastilina',
            'Hacer un cuenco con barro de secado rápido',
            'Modelar una pequeña estatua en pasta de sal',
            'Crear un jarrón con arcilla de secado al aire',
            'Hacer una figura abstracta con pasta de modelar',
            'Modelar una joya en arcilla polimérica',
            'Crear una pieza decorativa en plastilina',
            'Hacer un adorno para la casa en arcilla',
            'Crear una mini escultura en pasta de sal',
            'Modelar una taza en cerámica casera',
            'Hacer una pequeña maceta de arcilla',
            'Modelar una figura mitológica en plastilina',
            'Crear una figura decorativa con pasta de modelar',
            'Hacer un plato decorativo en arcilla',
            'Modelar un adorno de pared',
            'Hacer un colgante en arcilla polimérica',
            'Modelar un recipiente decorativo'
        ],
        'Grabado': [
            'Hacer un grabado simple en linóleo',
            'Crear un sello de goma personalizado',
            'Grabar una imagen en madera',
            'Hacer un grabado de relieve en papel',
            'Crear un grabado en cartón',
            'Hacer un sello decorativo con goma eva',
            'Grabar un diseño floral en linóleo',
            'Hacer una serie de grabados en papel reciclado',
            'Grabar un patrón abstracto en madera fina',
            'Crear un grabado con espuma de manualidades',
            'Hacer una impresión de grabado en casa',
            'Grabar un diseño minimalista en cartón',
            'Crear un grabado en metal utilizando papel de aluminio',
            'Hacer una impresión de grabado con pintura',
            'Grabar un diseño simple en linóleo casero',
            'Crear una tarjeta de felicitación grabada',
            'Hacer un póster de grabado casero',
            'Grabar un patrón geométrico',
            'Hacer una obra de arte con grabado en papel',
            'Crear un grabado en relieve de flores'
        ],
        'Joyería': [
            'Hacer un collar con abalorios',
            'Crear una pulsera de hilo',
            'Hacer unos pendientes con cuentas',
            'Crear un colgante de arcilla',
            'Hacer un anillo con alambre',
            'Crear una gargantilla tejida',
            'Hacer un collar con materiales reciclados',
            'Crear unos pendientes de resina casera',
            'Hacer una pulsera con charms',
            'Crear un broche con fieltro',
            'Hacer una diadema decorada',
            'Crear una joya en arcilla polimérica',
            'Hacer una pulsera de macramé',
            'Crear un collar de cuentas de madera',
            'Hacer unos pendientes colgantes',
            'Crear un anillo con cuentas',
            'Hacer un brazalete con cuero reciclado',
            'Crear un collar sencillo con hilo y cuentas',
            'Hacer un colgante con alambre y piedras',
            'Crear una joya personalizada con materiales de casa'
        ],
        'Artesanía en papel': [
            'Hacer flores de papel',
            'Crear una tarjeta de felicitación',
            'Hacer un marco de fotos de papel',
            'Crear una guirnalda de papel',
            'Hacer un adorno navideño con papel reciclado',
            'Crear una máscara de papel',
            'Hacer un collage artístico',
            'Crear una lámpara de papel',
            'Hacer una mariposa de origami',
            'Crear una escultura en papel maché',
            'Hacer un cuaderno artesanal',
            'Crear una corona decorativa de papel',
            'Hacer un móvil decorativo con figuras de papel',
            'Crear una caja de regalo decorada con papel',
            'Hacer una tarjeta pop-up',
            'Crear una obra de arte en papel de colores',
            'Hacer una maqueta sencilla en papel',
            'Crear una caja decorativa con cartulina',
            'Hacer figuras geométricas con papel reciclado',
            'Crear un objeto decorativo de origami'
        ],
        'Manualidades con materiales reciclados': [
            'Hacer una maceta con botellas de plástico',
            'Crear un organizador de escritorio con latas',
            'Hacer una lámpara con envases reciclados',
            'Crear una cesta con periódicos viejos',
            'Hacer una decoración de pared con botellas de vidrio',
            'Crear una bolsa de compras con ropa vieja',
            'Hacer una caja organizadora con cartón',
            'Crear una figura decorativa con botellas de plástico',
            'Hacer una lámpara de mesa con materiales reciclados',
            'Crear una funda de móvil con jeans reciclados',
            'Hacer un adorno navideño con cartón reciclado',
            'Crear un jarrón con botellas de vidrio',
            'Hacer una figura decorativa con objetos reciclados',
            'Crear un organizador de cables con rollos de papel',
            'Hacer una decoración de jardín con envases de plástico',
            'Crear una lámpara de techo con cucharas de plástico recicladas',
            'Hacer un marco de fotos con materiales reciclados',
            'Crear un estuche de lápices con botellas de plástico',
            'Hacer una bolsa para la compra con camisetas viejas',
            'Crear un colgador de llaves con piezas recicladas'
        ]
    },
    'Cocina': {
        'Repostería': [
            'Hornear un pastel de {sabor}',
            'Preparar galletas de {ingrediente}',
            'Hacer pan casero con {tipo}',
            'Crear cupcakes decorados de {tema}',
            'Preparar tarta de {fruta}',
            'Hacer brownies con caramelo salado',
            'Cocinar muffins de lo que tengas en el frigorífico',
            'Elaborar macarons de tu fruta preferida',
            'Preparar tiramisú casero',
            'Hacer churros con {salsa}',
            'Crear helado casero de {sabor}',
            'Hornear quiche de puerros',
            'Preparar cheesecake con {topping}',
            'Hacer donuts glaseados',
            'Cocinar flan de {sabor}',
            'Elaborar crepes con {relleno}',
            'Preparar panna cotta de {sabor}',
            'Hacer croissants caseros',
            'Cocinar pastel de zanahoria',
            'Crear tarta de manzana tradicional'
        ],
        'Cocina Internacional': [
            'Cocinar sushi de {tipo}',
            'Preparar paella de {ingrediente}',
            'Hacer tacos de {relleno}',
            'Cocinar curry {tipo}',
            'Preparar pasta casera con {salsa}',
            'Hacer ensalada {estilo}',
            'Cocinar ramen de {ingredientes}',
            'Preparar hummus con {variacion}',
            'Hacer falafel casero',
            'Cocinar pizza con {ingredientes}',
            'Preparar dim sum de {relleno}',
            'Hacer moussaka griega',
            'Cocinar schnitzel austríaco',
            'Preparar ceviche de {pescado}',
            'Hacer pad thai de {proteina}',
            'Cocinar empanadas argentinas',
            'Preparar bobotie sudafricano',
            'Hacer kimchi coreano',
            'Cocinar laksa malayo',
            'Preparar tagine marroquí'
        ],
        'Cocina Saludable': [
            'Preparar una ensalada con {ingredientes}',
            'Cocinar quinoa con verduras',
            'Hacer un smoothie de {fruta}',
            'Preparar avena con frutas para el desayuno',
            'Cocinar pescado al vapor con especias',
            'Hacer una tortilla de claras de huevo',
            'Preparar un batido verde con {ingrediente}',
            'Cocinar pollo al horno con hierbas',
            'Hacer wraps de lechuga con {relleno}',
            'Preparar arroz integral con brócoli',
            'Hacer palitos de zanahoria con hummus',
            'Preparar una ensalada de legumbres',
            'Hacer una pizza saludable con masa de coliflor',
            'Preparar tostadas de aguacate y tomate',
            'Cocinar un salteado de tofu y verduras',
            'Hacer un bol de yogur con frutos secos',
            'Preparar pescado en papillote',
            'Hacer chips de kale al horno',
            'Preparar un poke bowl de salmón',
            'Hacer hummus casero con {variacion}'
        ],
        'Cocina Rápida': [
            'Preparar un sándwich de {ingrediente}',
            'Hacer una tortilla francesa',
            'Cocinar espaguetis con salsa rápida de tomate',
            'Preparar un salteado exprés de pollo y verduras',
            'Hacer una quesadilla con {relleno}',
            'Cocinar arroz frito con huevo',
            'Preparar una ensalada de pasta',
            'Hacer un omelette relleno de {ingrediente}',
            'Cocinar una hamburguesa casera rápida',
            'Preparar un salteado de gambas con ajo',
            'Hacer una ensalada de atún',
            'Preparar un wrap de pollo y verduras',
            'Cocinar un salteado de fideos con {ingrediente}',
            'Hacer una pizza rápida en sartén',
            'Preparar tostadas con huevos pochados',
            'Cocinar fideos instantáneos con verduras',
            'Hacer un bol de arroz con pollo',
            'Preparar tacos rápidos de carne',
            'Cocinar pechugas de pollo a la plancha',
            'Hacer tostadas francesas con canela'
        ],
        'Cocina Vegana': [
            'Preparar una ensalada de quinoa y aguacate',
            'Hacer hamburguesas veganas de garbanzos',
            'Cocinar un curry de verduras con {tipo}',
            'Preparar un batido vegano con {ingrediente}',
            'Hacer una tortilla sin huevo con harina de garbanzo',
            'Cocinar lentejas estofadas con especias',
            'Preparar un bol de smoothie de frutas',
            'Hacer una pizza vegana con vegetales',
            'Cocinar tofu salteado con brócoli',
            'Preparar hummus de remolacha',
            'Hacer albóndigas veganas de lentejas',
            'Cocinar un wok de verduras y tofu',
            'Preparar falafel al horno',
            'Hacer espaguetis de calabacín con pesto vegano',
            'Cocinar una crema de calabaza vegana',
            'Preparar tacos de soja texturizada',
            'Hacer una lasaña de berenjena y lentejas',
            'Cocinar arroz con coco y plátano',
            'Preparar una sopa de miso vegana',
            'Hacer galletas veganas de avena y plátano'
        ],
        'Cocina de Aprovechamiento': [
            'Hacer croquetas con sobras de pollo',
            'Preparar una tortilla de patatas con sobras',
            'Cocinar un arroz frito con restos de verduras',
            'Hacer un salteado de pasta con restos de comida',
            'Preparar una ensalada con sobras de legumbres',
            'Cocinar una sopa de pollo con restos',
            'Hacer un pastel de carne con sobras',
            'Preparar un bol de arroz con restos de pescado',
            'Cocinar empanadas con restos de guiso',
            'Hacer un puré con sobras de verduras',
            'Preparar un quiche con sobras de queso y jamón',
            'Cocinar un estofado con restos de carne',
            'Hacer una lasaña con restos de comida',
            'Preparar una pizza con sobras de vegetales',
            'Cocinar una crema de verduras con sobras',
            'Hacer fajitas con restos de pollo',
            'Preparar un arroz al horno con restos de paella',
            'Cocinar una frittata con restos de pasta',
            'Hacer pan rallado con pan duro',
            'Preparar una sopa de pescado con restos'
        ],
        'Cocina Festiva': [
            'Preparar pavo relleno para Navidad',
            'Hacer turrón casero con almendras',
            'Cocinar roscones de Reyes',
            'Preparar ponche navideño',
            'Hacer una ensalada de Nochebuena',
            'Cocinar cochinillo al horno',
            'Preparar polvorones caseros',
            'Hacer mazapán con {ingrediente}',
            'Cocinar bacalao a la vizcaína para Navidad',
            'Preparar galletas navideñas decoradas',
            'Hacer pastel de carne para Acción de Gracias',
            'Cocinar una paella para celebrar un evento',
            'Preparar pavo de Acción de Gracias',
            'Hacer cupcakes festivos con {tema}',
            'Cocinar cordero al horno para Año Nuevo',
            'Preparar ensalada de frutas festiva',
            'Hacer bombones caseros para San Valentín',
            'Cocinar un asado festivo con verduras',
            'Preparar una tarta de cumpleaños con {tema}',
            'Hacer panettone casero'
        ],
        'Sopas y Cremas': [
            'Cocinar una sopa de pollo con fideos',
            'Preparar crema de calabacín',
            'Hacer una sopa de tomate con albahaca',
            'Cocinar sopa de cebolla gratinada',
            'Preparar una crema de zanahoria y jengibre',
            'Hacer caldo de pollo casero',
            'Cocinar una sopa de miso con tofu',
            'Preparar crema de champiñones',
            'Hacer sopa de lentejas con verduras',
            'Cocinar sopa de marisco',
            'Preparar una crema de espárragos',
            'Hacer sopa de ajo castellana',
            'Cocinar una crema de puerro y patata',
            'Preparar sopa minestrone',
            'Hacer caldo gallego',
            'Cocinar sopa de verduras con fideos',
            'Preparar crema de espinacas',
            'Hacer sopa de pescado con azafrán',
            'Cocinar crema de coliflor',
            'Preparar sopa de albóndigas'
        ],
        'Platos Principales': [
            'Cocinar pollo al curry con {tipo}',
            'Preparar lasaña de carne y verduras',
            'Hacer risotto de setas',
            'Cocinar estofado de ternera con patatas',
            'Preparar salmón al horno con eneldo',
            'Hacer albóndigas en salsa de tomate',
            'Cocinar costillas de cerdo al horno',
            'Preparar fajitas de pollo con pimientos',
            'Hacer musaka de berenjenas y carne',
            'Cocinar filetes de pescado empanizados',
            'Preparar pollo tikka masala',
            'Hacer bistec a la parrilla con especias',
            'Cocinar paella de mariscos',
            'Preparar carne mechada con arroz',
            'Hacer cordero al romero con patatas',
            'Cocinar pescado a la plancha con ajo',
            'Preparar solomillo de cerdo con mostaza',
            'Hacer hamburguesas caseras de ternera',
            'Cocinar pimientos rellenos de carne',
            'Preparar pollo a la cerveza'
        ],
        'Salsas y Aderezos': [
            'Preparar salsa boloñesa',
            'Hacer salsa bechamel con {ingrediente}',
            'Preparar guacamole casero',
            'Hacer aderezo de miel y mostaza',
            'Preparar salsa de yogur y pepino',
            'Hacer mayonesa casera',
            'Preparar salsa de tomate frito',
            'Hacer pesto de albahaca',
            'Preparar salsa tártara',
            'Hacer alioli con ajo',
            'Preparar vinagreta de mostaza y miel',
            'Hacer salsa de champiñones para carnes',
            'Preparar aderezo de cilantro y lima',
            'Hacer salsa de soja y jengibre',
            'Preparar salsa marinara',
            'Hacer aderezo de ajo y limón',
            'Preparar salsa de queso azul',
            'Hacer aderezo balsámico con miel',
            'Preparar salsa carbonara',
            'Hacer salsa de arándanos para carnes'
        ]

    },
    'Ejercicio y Fitness en Casa': {
        'Yoga': [
            'Practicar yoga de relajación con Youtube en casa',
            'Hacer una rutina de yoga matutino para {beneficio}',
            'Probar yoga restaurativo con música relajante',
            'Realizar una sesión de vinyasa yoga',
            'Practicar asanas de equilibrio como {postura}',
            'Seguir una clase de yoga para principiantes en {plataforma}',
            'Hacer una secuencia de yoga para fortalecer {parte del cuerpo}',
            'Probar una rutina de yoga para reducir el estrés',
            'Practicar yoga nidra para mejorar el sueño',
            'Hacer una clase de yoga con énfasis en la respiración',
            'Realizar una secuencia de yoga en pareja en casa',
            'Probar una rutina de power yoga para quemar calorías',
            'Practicar asanas de flexibilidad para {beneficio}',
            'Seguir una clase de yoga en silla para aliviar tensiones',
            'Probar una clase de yoga dinámico',
            'Practicar yoga con énfasis en la apertura de caderas',
            'Hacer una sesión de yoga flow para mejorar la circulación',
            'Practicar yoga kundalini para conectar con la energía interior',
            'Realizar una clase de yoga suave antes de dormir',
            'Probar yoga con meditación guiada para calmar la mente'
        ],
        'Pilates': [
            'Hacer una rutina de pilates para fortalecer el core en casa',
            'Seguir una clase de pilates con Youtube para tonificar brazos',
            'Practicar pilates con banda elástica para {parte del cuerpo}',
            'Realizar ejercicios de pilates con balón en casa',
            'Probar una clase de pilates de suelo para mejorar la postura',
            'Practicar pilates en colchoneta para alinear la columna',
            'Hacer una rutina de pilates para principiantes en {plataforma}',
            'Seguir una clase de pilates avanzado para tonificar glúteos',
            'Practicar pilates con pesas ligeras para fortalecer el tronco',
            'Realizar una rutina de pilates para mejorar la flexibilidad',
            'Probar una clase de pilates en pareja en casa',
            'Practicar pilates con énfasis en la movilidad articular',
            'Hacer una rutina de pilates matutino para activar el cuerpo',
            'Seguir una clase de pilates para aliviar dolores de espalda',
            'Probar una sesión de pilates con movimientos de respiración',
            'Practicar pilates en silla para mejorar la postura corporal',
            'Hacer una rutina de pilates con foam roller para masajear músculos',
            'Seguir una clase de pilates de bajo impacto en {plataforma}',
            'Practicar pilates con ejercicios para fortalecer el suelo pélvico',
            'Hacer una rutina de pilates intermedio para tonificar abdomen'
        ],
        'Cardio': [
            'Realizar una rutina de cardio HIIT en casa',
            'Seguir una clase de cardio de bajo impacto para {beneficio}',
            'Hacer ejercicios de cardio con cuerda para saltar en casa',
            'Practicar una rutina de cardio para quemar grasa en {plataforma}',
            'Probar una sesión de cardio kickboxing para aumentar la resistencia',
            'Hacer una rutina de cardio con baile para quemar calorías',
            'Seguir una clase de cardio con movimientos aeróbicos en casa',
            'Practicar ejercicios de cardio al ritmo de tu música favorita',
            'Hacer una rutina de cardio con énfasis en saltos pliométricos',
            'Seguir una sesión de cardio en pareja en casa',
            'Realizar una clase de cardio con ejercicios para mejorar el corazón',
            'Probar una rutina de cardio con movimientos funcionales en {plataforma}',
            'Hacer una rutina de cardio con intervalos para acelerar el metabolismo',
            'Practicar una sesión de cardio de alta intensidad con pesas ligeras',
            'Seguir una clase de cardio con pasos de baile en casa',
            'Realizar una rutina de cardio con movimientos de boxeo en casa',
            'Probar una rutina de cardio para fortalecer piernas y glúteos',
            'Hacer una clase de cardio con ejercicios para aumentar la resistencia',
            'Practicar una rutina de cardio sin equipo en casa',
            'Seguir una clase de cardio HIIT en {plataforma}'
        ],
        'Fuerza': [
            'Hacer una rutina de fuerza con pesas ligeras para fortalecer brazos',
            'Practicar ejercicios de fuerza con mancuernas en casa',
            'Seguir una clase de fuerza con pesas rusas en casa',
            'Hacer una rutina de fuerza para tonificar las piernas en {plataforma}',
            'Probar una sesión de fuerza con ejercicios para el core en casa',
            'Practicar una rutina de fuerza utilizando bandas de resistencia',
            'Hacer una sesión de fuerza con peso corporal en casa',
            'Seguir una clase de fuerza enfocada en glúteos y muslos en {plataforma}',
            'Practicar una rutina de fuerza con kettlebell en casa',
            'Hacer una sesión de fuerza de alta intensidad para el tren superior',
            'Probar ejercicios de fuerza con silla para trabajar el core',
            'Seguir una clase de fuerza con ejercicios de isometría en casa',
            'Hacer una rutina de fuerza con movimientos de empuje y tracción',
            'Practicar una sesión de fuerza para mejorar la estabilidad corporal',
            'Seguir una rutina de fuerza para aumentar la masa muscular',
            'Probar una clase de fuerza con pesas ajustables en casa',
            'Hacer una rutina de fuerza con repeticiones para brazos y pecho',
            'Practicar ejercicios de fuerza en circuitos para todo el cuerpo',
            'Seguir una clase de fuerza con ejercicios para la parte baja del cuerpo',
            'Hacer una rutina de fuerza funcional en {plataforma}'
        ],
        'Flexibilidad': [
            'Hacer una rutina de estiramientos para mejorar la flexibilidad',
            'Practicar ejercicios de flexibilidad en casa con ayuda de una banda',
            'Seguir una clase de flexibilidad para mejorar la movilidad de caderas',
            'Hacer una sesión de estiramientos dinámicos para el tren inferior',
            'Probar una rutina de flexibilidad para aliviar dolores de espalda',
            'Practicar estiramientos de flexibilidad para el tren superior',
            'Hacer una rutina de estiramientos de yoga para mejorar la flexibilidad',
            'Seguir una clase de flexibilidad con ejercicios para todo el cuerpo',
            'Probar una sesión de estiramientos activos para piernas y brazos',
            'Hacer una rutina de flexibilidad con movimientos de apertura',
            'Practicar una sesión de flexibilidad con ejercicios para la columna',
            'Hacer una rutina de estiramientos suaves antes de dormir',
            'Seguir una clase de flexibilidad para mejorar la amplitud de movimiento',
            'Hacer una sesión de estiramientos para fortalecer el core',
            'Practicar una rutina de flexibilidad con movimientos fluidos',
            'Probar una clase de flexibilidad con estiramientos para mejorar la postura',
            'Hacer una rutina de flexibilidad con movimientos de yoga en casa',
            'Seguir una clase de flexibilidad para preparar el cuerpo para el ejercicio',
            'Practicar una sesión de estiramientos activos y estáticos en casa',
            'Hacer una rutina de flexibilidad para prevenir lesiones'
        ],
        'Aeróbicos': [
            'Realizar una clase de aeróbicos de bajo impacto en casa',
            'Seguir una rutina de aeróbicos con pasos básicos en {plataforma}',
            'Hacer una sesión de aeróbicos con movimientos coordinados en casa',
            'Practicar una rutina de aeróbicos para quemar calorías rápidamente',
            'Probar una sesión de aeróbicos con música rítmica en casa',
            'Hacer una clase de aeróbicos para tonificar el cuerpo en casa',
            'Seguir una rutina de aeróbicos con ejercicios coreografiados en {plataforma}',
            'Practicar una sesión de aeróbicos en pareja en casa',
            'Hacer una rutina de aeróbicos con movimientos de bajo impacto',
            'Probar una clase de aeróbicos para aumentar la resistencia',
            'Hacer una rutina de aeróbicos con pasos de baile en casa',
            'Practicar una sesión de aeróbicos de alta energía en casa',
            'Seguir una clase de aeróbicos con movimientos sencillos para principiantes',
            'Hacer una rutina de aeróbicos con ejercicios para mejorar el ritmo cardiovascular',
            'Practicar una sesión de aeróbicos para tonificar piernas y brazos',
            'Probar una clase de aeróbicos con música de los 80 en casa',
            'Hacer una rutina de aeróbicos con movimientos coordinados',
            'Seguir una sesión de aeróbicos con ejercicios para todo el cuerpo',
            'Practicar una clase de aeróbicos con música latina en {plataforma}',
            'Hacer una rutina de aeróbicos con pasos rápidos en casa'
        ],
        'Entrenamiento Funcional': [
            'Hacer una rutina de entrenamiento funcional con movimientos multiarticulares',
            'Seguir una clase de entrenamiento funcional para mejorar la resistencia',
            'Practicar ejercicios de entrenamiento funcional con pesas ligeras',
            'Hacer una rutina de entrenamiento funcional en circuito en casa',
            'Probar una sesión de entrenamiento funcional para todo el cuerpo',
            'Seguir una clase de entrenamiento funcional para mejorar la movilidad',
            'Hacer una rutina de entrenamiento funcional con ejercicios de fuerza y cardio',
            'Practicar una sesión de entrenamiento funcional con movimientos funcionales en casa',
            'Hacer una clase de entrenamiento funcional con énfasis en el core',
            'Probar una rutina de entrenamiento funcional de alta intensidad',
            'Seguir una clase de entrenamiento funcional para mejorar la coordinación',
            'Practicar una rutina de entrenamiento funcional con pesas y bandas',
            'Hacer una sesión de entrenamiento funcional con ejercicios de equilibrio',
            'Probar una clase de entrenamiento funcional con movimientos compuestos',
            'Seguir una rutina de entrenamiento funcional para mejorar la fuerza',
            'Practicar ejercicios de entrenamiento funcional para la estabilidad en casa',
            'Hacer una rutina de entrenamiento funcional con pesas rusas en casa',
            'Seguir una clase de entrenamiento funcional para tonificar todo el cuerpo',
            'Practicar una rutina de entrenamiento funcional con ejercicios dinámicos',
            'Hacer una clase de entrenamiento funcional de bajo impacto'
        ],
        'Danza Fitness': [
            'Hacer una rutina de danza fitness con coreografía',
            'Seguir una clase de zumba fitness en {plataforma}',
            'Practicar una sesión de danza fitness con movimientos de salsa en casa',
            'Hacer una rutina de danza fitness con ritmos latinos en casa',
            'Probar una clase de danza fitness de alta intensidad para quemar calorías',
            'Seguir una rutina de danza fitness para tonificar el cuerpo completo',
            'Practicar una sesión de danza fitness con pasos de hip-hop en casa',
            'Hacer una clase de danza fitness con movimientos de merengue',
            'Probar una rutina de danza fitness de bajo impacto en casa',
            'Seguir una sesión de danza fitness en pareja en casa',
            'Hacer una clase de danza fitness con música de los 90 en casa',
            'Practicar una rutina de danza fitness con pasos de cumbia en {plataforma}',
            'Probar una clase de danza fitness con música africana en casa',
            'Seguir una rutina de danza fitness con movimientos de flamenco',
            'Hacer una sesión de danza fitness con coreografía de reggaetón en casa',
            'Practicar una clase de danza fitness para mejorar la coordinación',
            'Probar una rutina de danza fitness con movimientos de bachata',
            'Seguir una sesión de danza fitness con ejercicios de calentamiento en {plataforma}',
            'Hacer una clase de danza fitness con música pop en casa',
            'Practicar una rutina de danza fitness con pasos de breakdance'
        ],
        'Calistenia': [
            'Hacer una rutina de calistenia para fortalecer el tren superior',
            'Practicar una clase de calistenia en casa sin equipo',
            'Seguir una rutina de calistenia con movimientos de fuerza en {plataforma}',
            'Hacer una sesión de calistenia con ejercicios de cuerpo completo',
            'Probar una rutina de calistenia avanzada para mejorar la resistencia',
            'Practicar una clase de calistenia con movimientos de empuje y tracción',
            'Hacer una rutina de calistenia para tonificar las piernas',
            'Seguir una sesión de calistenia con ejercicios para el core en casa',
            'Probar una rutina de calistenia con ejercicios para mejorar la flexibilidad',
            'Hacer una clase de calistenia con movimientos pliométricos en casa',
            'Practicar una sesión de calistenia con énfasis en los glúteos en {plataforma}',
            'Probar una rutina de calistenia para aumentar la fuerza en casa',
            'Hacer una clase de calistenia con ejercicios para fortalecer el core',
            'Seguir una rutina de calistenia con movimientos para mejorar la movilidad',
            'Practicar una sesión de calistenia con ejercicios para todo el cuerpo',
            'Probar una rutina de calistenia de nivel intermedio en casa',
            'Hacer una clase de calistenia para aumentar la resistencia cardiovascular',
            'Seguir una sesión de calistenia con ejercicios de bajo impacto en casa',
            'Practicar una rutina de calistenia con énfasis en el control corporal',
            'Probar una clase de calistenia con ejercicios para tonificar brazos y pecho'
        ],
        'Meditación y Relajación Física': [
            'Hacer una sesión de meditación guiada para reducir el estrés',
            'Practicar meditación de atención plena en casa con Youtube',
            'Seguir una clase de meditación para mejorar la concentración',
            'Hacer una sesión de meditación con respiración profunda en casa',
            'Probar una clase de meditación para principiantes en {plataforma}',
            'Practicar meditación en silencio para calmar la mente',
            'Seguir una sesión de meditación de amor y bondad en casa',
            'Hacer una rutina de meditación con visualizaciones guiadas',
            'Probar una clase de meditación zen para reducir la ansiedad',
            'Practicar una sesión de meditación activa en casa',
            'Hacer una rutina de relajación muscular progresiva en casa',
            'Seguir una clase de meditación para mejorar el sueño en {plataforma}',
            'Probar una sesión de meditación trascendental en casa',
            'Hacer una rutina de meditación con música relajante en casa',
            'Practicar una clase de meditación para mejorar la autocompasión',
            'Seguir una sesión de meditación para liberar tensiones en casa',
            'Hacer una rutina de meditación con ejercicios de respiración consciente',
            'Probar una clase de meditación para conectar con la naturaleza en {plataforma}',
            'Practicar una sesión de meditación guiada para relajarse antes de dormir',
            'Hacer una rutina de meditación para liberar emociones negativas'
        ]
    },
    'Juegos de Mesa y Entretenimiento': {
        'Cartas': [
            'Jugar una partida de póker con amigos en casa',
            'Organizar un torneo de UNO',
            'Aprender a jugar bridge con tutoriales en {plataforma}',
            'Jugar una partida de solitario con una baraja clásica',
            'Probar un juego de cartas coleccionables como {juego}',
            'Hacer una partida de cartas rápidas con alguien',
            'Organizar una noche de juegos de cartas familiares en casa',
            'Jugar a las cartas con las reglas personalizadas de {juego}',
            'Aprender trucos de magia con cartas en {plataforma}',
            'Jugar una partida de blackjack en casa con familia o amigos',
            'Practicar trucos de habilidad con una baraja de cartas',
            'Hacer una partida de mus en casa con amigos',
            'Probar el juego de cartas de rol en vivo con {tema}',
            'Jugar a la escalera con una baraja española',
            'Organizar una noche de póker temático en casa',
            'Jugar al tute con una baraja de cartas española',
            'Practicar el juego de cartas "Hearts" con amigos',
            'Hacer una ronda de Gin Rummy en pareja en casa',
            'Jugar a las cartas con la familia usando una baraja personalizada',
            'Probar una partida de cartas de coleccionista en {tema}'
        ],
        'Estrategia': [
            'Jugar una partida de ajedrez con un amigo en casa',
            'Organizar una partida de Risk',
            'Probar un juego de estrategia en tiempo real como {juego}',
            'Jugar una partida de Catan en familia para conquistar territorios',
            'Aprender a jugar Diplomacy con tutoriales en {plataforma}',
            'Organizar una sesión de Carcassonne con reglas avanzadas',
            'Jugar una partida de Twilight Struggle con un oponente en casa',
            'Probar un juego de estrategia cooperativa como {juego}',
            'Hacer una sesión de planificación en el juego Pandemic',
            'Organizar una partida de estrategia militar con miniaturas en {tema}',
            'Probar un juego de estrategia económica como {juego}',
            'Jugar una ronda de Ticket to Ride en casa',
            'Organizar una partida de Twilight Imperium.',
            'Jugar una partida de estrategia por turnos en Civilization en casa',
            'Probar un juego de construcción de ciudades como SimCity en mesa',
            'Jugar a la gestión de recursos en Agricola con la familia',
            'Organizar una campaña de Dune para competir por el control del planeta',
            'Probar un juego de estrategia espacial como Eclipse en {plataforma}',
            'Jugar una partida de Dominion',
            'Hacer una sesión de estrategia en X-Wing con miniaturas'
        ],
        'Trivia': [
            'Organizar una noche de trivia temática sobre {tema}',
            'Jugar a Trivial Pursuit con la familia en casa',
            'Probar un juego de preguntas rápidas en {plataforma}',
            'Hacer una ronda de preguntas sobre cultura general en casa',
            'Jugar a un juego de trivia basado en películas antiguas',
            'Organizar un torneo de preguntas de historia en casa',
            'Probar un juego de preguntas y respuestas rápidas en equipo',
            'Jugar a un juego de trivia musical con canciones de {década}',
            'Hacer una partida de preguntas deportivas sobre algún tipo de deporte',
            'Jugar una ronda de trivia sobre tecnología con amigos',
            'Organizar una sesión de preguntas de ciencia en casa',
            'Probar un juego de trivia de geografía mundial',
            'Hacer una sesión de trivia temática sobre series de televisión',
            'Jugar a un juego de preguntas de cultura pop con la familia',
            'Probar un juego de preguntas sobre comida y gastronomía en {plataforma}',
            'Organizar una sesión de trivia sobre literatura clásica',
            'Hacer una partida de preguntas de historia del arte en casa',
            'Jugar a un juego de trivia sobre videojuegos retro en casa',
            'Probar un juego de preguntas sobre mitología en {plataforma}',
            'Organizar una ronda de trivia con preguntas personalizadas'
        ],
        'Habilidad': [
            'Organizar una partida de Jenga en familia en casa',
            'Probar el juego de habilidad Twister con amigos',
            'Jugar una ronda de Mikado para mejorar la destreza manual',
            'Hacer una partida de Flick ‘Em Up en casa',
            'Practicar el equilibrio en una partida de Kapla con alguien',
            'Jugar a una ronda de juegos de habilidad',
            'Probar el juego de habilidad "La Torre de Colores" con la familia',
            'Organizar una competición de destreza en casa con juegos clásicos',
            'Jugar a una ronda de Tiddlywinks con amigos',
            'Probar una partida de Crokinole',
            'Organizar una sesión de juegos de habilidad con manos rápidas en casa',
            'Practicar destrezas manuales con un set de Kendama en casa',
            'Hacer una sesión de habilidad con un juego de mesa como Tumblin’ Dice',
            'Jugar a un juego de habilidad con lanzamientos de anillos en casa',
            'Probar una ronda de PitchCar en {plataforma}',
            'Jugar una partida de Clask con movimientos rápidos en casa',
            'Organizar una ronda de juegos de destreza como Carrom con amigos',
            'Practicar habilidades de precisión con un set de Sapo en casa',
            'Probar una partida de Pucket para mejorar la coordinación',
            'Jugar una ronda de Pitcher con la familia en casa'
        ],
        'Rol': [
            'Organizar una partida de Dungeons & Dragons en casa',
            'Probar una sesión de rol en vivo con la familia en casa',
            'Hacer una campaña de rol en mesa con ambientación de fantasía',
            'Jugar una partida de rol narrativo con personajes de {tema}',
            'Probar una sesión de rol de horror cósmico en casa',
            'Organizar una partida de rol de investigación en casa',
            'Jugar una sesión de rol en solitario con un set de aventuras rápidas',
            'Probar una partida de rol de ciencia ficción con reglas caseras',
            'Hacer una campaña de rol por turnos con amigos en {plataforma}',
            'Jugar una partida de rol con temática de superhéroes en casa',
            'Probar una sesión de rol de misterio con pistas en casa',
            'Organizar una campaña de rol con ambientación medieval en casa',
            'Jugar una partida de rol cooperativo en un mundo postapocalíptico',
            'Probar una sesión de rol de viajes en el tiempo en {plataforma}',
            'Hacer una campaña de rol de detectives con escenarios urbanos',
            'Jugar una partida de rol de piratas con personajes creados en casa',
            'Organizar una sesión de rol de exploración espacial en casa',
            'Probar una partida de rol de terror psicológico con la familia',
            'Hacer una campaña de rol de intrigas políticas en un reino imaginario',
            'Jugar una partida de rol de aventuras épicas con un grupo de varias personas'
        ],
        'Dados': [
            'Organizar una partida de Yahtzee con la familia en casa',
            'Probar una sesión de lanzamiento de dados en juegos de rol en mesa',
            'Hacer una ronda de dados rápidos con amigos en casa',
            'Jugar una partida de Liar’s Dice con reglas personalizadas',
            'Probar un juego de dados de construcción de ciudades en {plataforma}',
            'Hacer una ronda de Farkle para mejorar la suerte en los dados',
            'Organizar una partida de dados de azar en casa',
            'Jugar una sesión de lanzamiento de dados para crear personajes de rol',
            'Probar un juego de dados con temática espacial en {plataforma}',
            'Hacer una ronda de dados para conquistar territorios en Risk',
            'Organizar una competición de dados con el juego "Sagrada" en casa',
            'Probar un juego de dados de construcción de mazos en casa',
            'Jugar una ronda de dados con personajes de fantasía en mesa',
            'Probar un juego de dados cooperativo en casa',
            'Hacer una sesión de dados con reglas caseras de creación de historias',
            'Jugar una partida de dados de alta estrategia en {plataforma}',
            'Probar un juego de dados con enfoque en la narrativa en mesa',
            'Organizar una ronda de dados para resolver conflictos en un juego de rol',
            'Jugar una partida de dados con temas históricos en casa',
            'Probar un juego de dados de aventuras épicas con amigos en casa'
        ],
        'Palabras': [
            'Jugar una partida de Scrabble con la familia en casa',
            'Probar una sesión de Boggle para formar palabras rápidamente',
            'Hacer una ronda de Palabras Cruzadas con reglas avanzadas',
            'Jugar una partida de Bananagrams para formar palabras en tiempo real',
            'Probar un juego de palabras en {plataforma} con amigos',
            'Organizar una sesión de Spelling Bee en casa con la familia o amigos',
            'Jugar a una ronda de Palabras Encadenadas con amigos en casa',
            'Hacer una partida de Juego de Letras con un límite de tiempo',
            'Probar un juego de palabras temático sobre {tema}',
            'Jugar a un juego de creación de palabras rápidas con la familia',
            'Organizar una competición de palabras en casa con el juego Taboo',
            'Probar un juego de palabras en solitario como Wordle en {plataforma}',
            'Hacer una sesión de anagramas con palabras complejas en casa',
            'Jugar una partida de Palabras Ocultas con pistas en {plataforma}',
            'Probar un juego de palabras con pistas literarias en mesa',
            'Jugar una ronda de Cifras y Letras con reglas personalizadas',
            'Organizar una competición de creación de palabras en casa con amigos',
            'Probar una partida de palabras cooperativas en {plataforma}',
            'Hacer una ronda de palabras en juego de adivinanzas rápidas en mesa',
            'Jugar una partida de Scrabble con temáticas literarias en casa'
        ],
        'Memoria': [
            'Jugar una partida de Memoria con tarjetas temáticas de {tema}',
            'Organizar una competición de juegos de memoria visual en casa',
            'Probar un juego de memoria con cartas de personajes en {plataforma}',
            'Hacer una ronda de juegos de memoria con reglas avanzadas',
            'Jugar una sesión de memoria con imágenes y palabras en casa',
            'Probar un juego de memoria cooperativo con la familia',
            'Organizar una partida de Memory con imágenes de animales en casa',
            'Jugar una ronda de juegos de memoria visual con objetos de casa',
            'Hacer una sesión de juegos de memoria en pareja en casa',
            'Probar un juego de memoria con números y secuencias en mesa',
            'Jugar una partida de Memoria con símbolos en {plataforma}',
            'Organizar una sesión de juegos de memoria en equipos en casa',
            'Probar un juego de memoria auditiva en {plataforma}',
            'Jugar una ronda de Memoria en casa con cartas personalizadas',
            'Hacer una competición de juegos de memoria con formas y colores',
            'Probar un juego de memoria sensorial en casa',
            'Jugar una partida de Memoria con imágenes históricas en casa',
            'Hacer una sesión de juegos de memoria rápida con la familia',
            'Probar un juego de memoria en equipos para mejorar la atención',
            'Jugar una ronda de Memoria con figuras geométricas en mesa'
        ],
        'Cooperación': [
            'Jugar una partida cooperativa de Pandemic con amigos en casa',
            'Probar un juego de cooperación en tiempo real como {juego}',
            'Hacer una sesión cooperativa de Mysterium con la familia',
            'Organizar una partida de Forbidden Island en casa',
            'Probar un juego de cooperación basado en resolver misterios en {plataforma}',
            'Jugar una partida cooperativa de Codenames en casa',
            'Hacer una ronda de cooperación en juegos de mesa con amigos',
            'Probar una sesión cooperativa de juegos de construcción como {juego}',
            'Organizar una sesión de juegos de cooperación en equipos en casa',
            'Jugar una partida cooperativa de rol en mesa con personajes de {tema}',
            'Probar una ronda de cooperación para resolver acertijos en casa',
            'Hacer una sesión cooperativa de juegos de gestión de recursos en mesa',
            'Organizar una partida de juegos cooperativos de aventuras en casa',
            'Probar un juego de cooperación en línea con amigos en {plataforma}',
            'Jugar una partida cooperativa de exploración espacial en casa',
            'Hacer una sesión cooperativa de juegos de narrativa en mesa',
            'Probar una partida de cooperación para construir ciudades en mesa',
            'Organizar una sesión de juegos de cooperación para resolver crímenes en casa',
            'Jugar una ronda de cooperación para completar misiones en {plataforma}',
            'Hacer una sesión cooperativa en juegos de rol para resolver desafíos'
        ],
        'Puzzles': [
            'Hacer un puzzle de más de 1000 piezas en casa',
            'Organizar una sesión de montaje de puzzles en familia',
            'Probar un puzzle tridimensional para construir lo que quieras',
            'Jugar una partida de puzzles de lógica con amigos en {plataforma}',
            'Hacer un puzzle de paisajes en casa con la familia',
            'Probar un puzzle de arte clásico en {plataforma}',
            'Organizar una sesión de puzzles con desafíos matemáticos en casa',
            'Hacer un puzzle en solitario con imágenes de {tema}',
            'Probar una sesión de puzzles cooperativos con la familia',
            'Organizar una competición de puzzles de geometría en casa',
            'Hacer un puzzle temático sobre películas de terror',
            'Probar un puzzle con piezas de madera en {plataforma}',
            'Jugar una partida de puzzles de lógica rápida en casa',
            'Organizar una ronda de puzzles temáticos de {tema} en casa',
            'Hacer un puzzle de figuras abstractas en casa',
            'Probar un puzzle de rompecabezas en el móvil',
            'Organizar una competición de puzzles entre amigos en casa',
            'Hacer un puzzle de dificultad avanzada sobre {tema}',
            'Probar una sesión de puzzles con imágenes históricas en casa',
            'Hacer un puzzle en familia sobre lugares emblemáticos de {lugar}'
        ]
    },
    'Jardinería Interior': {
        'Cultivo de Hierbas': [
            'Plantar semillas de albahaca en macetas pequeñas',
            'Cultivar perejil en la cocina con luz natural',
            'Hacer un jardín de hierbas en macetas recicladas en casa',
            'Sembrar cilantro en macetas colgantes en casa',
            'Probar a cultivar menta en macetas pequeñas en la ventana',
            'Hacer un mini huerto de romero en la cocina',
            'Sembrar semillas de tomillo en macetas de cerámica',
            'Probar un kit de cultivo de hierbas aromáticas en casa',
            'Cultivar orégano en un jardín interior con luz LED',
            'Sembrar albahaca morada en macetas decorativas en casa',
            'Hacer un cultivo de hierbas mixtas en la terraza interior',
            'Plantar semillas de estragón en pequeños tiestos en la cocina',
            'Probar a cultivar cebollino en la ventana de la cocina',
            'Hacer un jardín vertical de hierbas en la pared de la cocina',
            'Sembrar semillas de salvia en macetas de barro en casa',
            'Cultivar eneldo en macetas recicladas con abono orgánico',
            'Probar a hacer un cultivo de hierbas aromáticas en bandejas en casa',
            'Hacer un cultivo hidropónico de menta en la cocina',
            'Sembrar semillas de cilantro en una mesa de cultivo interior',
            'Probar a cultivar lavanda en macetas pequeñas en casa'
        ],
        'Huerto en Casa': [
            'Sembrar tomates cherry en macetas grandes en la terraza',
            'Probar a cultivar fresas en jardineras colgantes en casa',
            'Hacer un huerto vertical de lechugas en la cocina',
            'Cultivar espinacas en macetas recicladas en casa',
            'Probar un kit de huerto urbano para plantar zanahorias en casa',
            'Sembrar calabacines en jardineras de madera en el balcón',
            'Hacer un cultivo de rábanos en macetas pequeñas en casa',
            'Probar a cultivar berenjenas en jardineras grandes en el interior',
            'Sembrar semillas de pepino en un huerto interior con luz LED',
            'Cultivar pimientos en macetas grandes dentro de la casa',
            'Hacer un huerto de hierbas y vegetales en casa',
            'Probar a cultivar col rizada en un huerto interior',
            'Sembrar guisantes en macetas colgantes en la cocina',
            'Cultivar zanahorias en jardineras alargadas en el balcón',
            'Probar a hacer un huerto hidropónico en casa con lechugas',
            'Sembrar remolachas en macetas profundas en casa',
            'Hacer un huerto de pimientos picantes en macetas recicladas',
            'Probar un cultivo de tomates en un jardín vertical interior',
            'Sembrar judías verdes en jardineras de barro dentro de casa',
            'Hacer un mini huerto de hierbas y hortalizas en la terraza'
        ],
        'Plantas de Interior': [
            'Plantar una sansevieria en una maceta decorativa en casa',
            'Probar a cultivar un potus en una maceta colgante en casa',
            'Hacer un rincón verde con una monstera deliciosa en el salón',
            'Plantar un ficus en una maceta grande en el recibidor',
            'Probar a cuidar un filodendro en un jardín interior',
            'Hacer un grupo de plantas suculentas en la ventana de la cocina',
            'Plantar una calathea en una maceta moderna en casa',
            'Probar a cuidar una planta de aloe vera en casa',
            'Hacer un jardín de interior con cactus en macetas pequeñas',
            'Plantar una zamioculca en una maceta grande en el salón',
            'Probar a cultivar una planta de jade en una mesa interior',
            'Hacer un grupo de plantas de sombra en un rincón del salón',
            'Plantar una alocasia en una maceta de cerámica en casa',
            'Probar a tener una dracaena en una maceta decorativa en casa',
            'Hacer un pequeño jardín interior con begonias en macetas',
            'Plantar una schefflera en un macetero grande en el recibidor',
            'Probar a cuidar una planta de espatifilo en el interior',
            'Hacer un rincón verde con helechos en el baño',
            'Plantar una planta de orquídea en la ventana del salón',
            'Probar a cultivar una peperomia en una maceta colgante en casa'
        ],
        'Jardines Verticales': [
            'Crear un jardín vertical de suculentas en casa',
            'Probar a hacer un jardín vertical de hierbas aromáticas en la cocina',
            'Montar un jardín vertical en el salón con plantas de interior',
            'Hacer un jardín vertical de flores en la pared de casa',
            'Probar un jardín vertical de helechos en el baño',
            'Crear un jardín vertical de plantas trepadoras en casa',
            'Hacer un jardín vertical de hierbas para la cocina',
            'Probar a hacer un jardín vertical de plantas de sombra en casa',
            'Montar un jardín vertical con macetas colgantes en la terraza',
            'Hacer un jardín vertical de musgo decorativo en la sala de estar',
            'Probar a crear un jardín vertical con un sistema hidropónico en casa',
            'Hacer un jardín vertical de plantas aromáticas en la cocina',
            'Crear un jardín vertical de plantas pequeñas en el recibidor',
            'Probar un jardín vertical de suculentas en el baño',
            'Hacer un jardín vertical con un marco de madera en casa',
            'Montar un jardín vertical con plantas tropicales en casa',
            'Probar un jardín vertical de cactus en la terraza',
            'Crear un jardín vertical de orquídeas en la pared del salón',
            'Hacer un jardín vertical con un sistema de riego automático en casa',
            'Probar a hacer un jardín vertical de lavandas en el balcón'
        ],
        'Bonsái y Árboles Pequeños': [
            'Cultivar un bonsái de ficus en la ventana de casa',
            'Probar a cuidar un bonsái de olmo en casa',
            'Hacer un bonsái de pino desde semilla en una maceta',
            'Cuidar un bonsái de arce en el salón con luz indirecta',
            'Probar a modelar un bonsái de serissa en casa',
            'Hacer un bonsái de cerezo en una maceta de cerámica',
            'Cuidar un bonsái de junípero en la terraza interior',
            'Probar a hacer un bonsái de manzano en casa',
            'Hacer un bonsái de ficus benjamina en el recibidor',
            'Cuidar un bonsái de higuera en una maceta grande',
            'Probar a modelar un bonsái de olivo en el salón',
            'Hacer un bonsái de ciprés en una maceta en la cocina',
            'Cuidar un bonsái de granado en el balcón',
            'Probar a hacer un bonsái de azalea en una mesa interior',
            'Hacer un bonsái de sauce en una maceta de barro en casa',
            'Cuidar un bonsái de gingko en una maceta decorativa',
            'Probar a cultivar un bonsái de almendro en casa',
            'Hacer un bonsái de tejo en una maceta pequeña en la terraza',
            'Cuidar un bonsái de espino en una mesa interior',
            'Probar a hacer un bonsái de laurel en casa'
        ],
        'Macetas Colgantes': [
            'Crear un grupo de macetas colgantes con suculentas en el balcón',
            'Probar a colgar macetas con plantas trepadoras en casa',
            'Hacer un jardín colgante de helechos en la terraza',
            'Colgar macetas de cactus en la ventana de casa',
            'Probar a colgar macetas con potus en la sala de estar',
            'Hacer un jardín colgante con plantas aromáticas en la cocina',
            'Colgar macetas con flores de temporada en casa',
            'Probar a colgar macetas de hierbas aromáticas en la ventana del salón',
            'Hacer un jardín colgante de hiedra en la pared de casa',
            'Colgar macetas con plantas tropicales en el baño',
            'Probar a hacer un jardín colgante con helechos en el recibidor',
            'Colgar macetas con geranios en el balcón',
            'Hacer un jardín colgante de lavandas en la terraza',
            'Colgar macetas con begonias en la ventana del salón',
            'Probar a hacer un jardín colgante de petunias en casa',
            'Colgar macetas con plantas de sombra en el interior de casa',
            'Hacer un jardín colgante de crasas en la cocina',
            'Colgar macetas con flores de interior en la sala de estar',
            'Probar a hacer un jardín colgante con plantas trepadoras en casa',
            'Colgar macetas con hiedras en el recibidor'
        ],
        'Flores de Interior': [
            'Plantar tulipanes en macetas pequeñas en la ventana del salón',
            'Probar a cultivar orquídeas en casa con luz indirecta',
            'Hacer un jardín de flores de interior en la terraza',
            'Plantar begonias en macetas de barro en casa',
            'Probar a cuidar lirios en macetas en el recibidor',
            'Hacer un jardín de violetas africanas en una mesa interior',
            'Plantar geranios en macetas pequeñas en la cocina',
            'Probar a cultivar claveles en el balcón de casa',
            'Hacer un jardín de flores mixtas en una terraza interior',
            'Plantar pensamientos en macetas grandes en el salón',
            'Probar a cultivar calas en macetas con luz indirecta en casa',
            'Hacer un rincón de flores de interior con rosas miniatura',
            'Plantar petunias en macetas decorativas en el salón',
            'Probar a cultivar margaritas en la terraza interior',
            'Hacer un jardín interior de flores de temporada en casa',
            'Plantar gladiolos en jardineras grandes en la terraza',
            'Probar a cultivar fresias en macetas en el balcón',
            'Hacer un rincón floral con lirios de la paz en casa',
            'Plantar begonias rex en macetas en el recibidor',
            'Probar a hacer un jardín de flores tropicales en casa'
        ],
        'Plantas Suculentas': [
            'Plantar una colección de cactus pequeños en casa',
            'Probar a cultivar echeverias en macetas de cerámica en el salón',
            'Hacer un rincón de suculentas en la ventana de la cocina',
            'Plantar crasas en macetas recicladas en casa',
            'Probar a cuidar haworthias en macetas decorativas en casa',
            'Hacer un jardín de suculentas en una maceta colgante en la terraza',
            'Plantar aloes en macetas pequeñas en el balcón',
            'Probar a cultivar sempervivums en macetas de barro en casa',
            'Hacer un jardín de cactus en una mesa de la sala de estar',
            'Plantar agaves en macetas grandes en la terraza interior',
            'Probar a hacer un jardín de suculentas en macetas colgantes',
            'Hacer un rincón de cactus con luz indirecta en casa',
            'Plantar graptopetalum en macetas pequeñas en la ventana del salón',
            'Probar a cultivar suculentas de colección en el baño',
            'Hacer un jardín interior de crasas en macetas de cerámica',
            'Plantar lithops en macetas decorativas en casa',
            'Probar a hacer un rincón de suculentas con luz natural en casa',
            'Hacer un jardín de suculentas en la terraza de casa',
            'Plantar aloe vera en una maceta pequeña en la cocina',
            'Probar a cultivar suculentas raras en macetas de barro en casa'
        ],
        'Terrarios': [
            'Hacer un terrario cerrado con plantas de interior en casa',
            'Probar a crear un terrario con suculentas en casa',
            'Hacer un terrario tropical con helechos en una mesa interior',
            'Crear un terrario en un frasco de vidrio con musgo y piedras',
            'Probar a hacer un terrario de cactus en una pecera pequeña',
            'Hacer un terrario colgante con plantas aéreas en el salón',
            'Crear un terrario de plantas carnívoras en casa',
            'Probar a hacer un terrario de musgo con figuras decorativas',
            'Hacer un terrario de suculentas en una botella de vidrio reciclada',
            'Crear un terrario de plantas de sombra en un recipiente de cristal',
            'Probar a hacer un terrario de flores pequeñas en la ventana de casa',
            'Hacer un terrario de crasas en una caja de vidrio en casa',
            'Crear un terrario con iluminación LED para suculentas en casa',
            'Probar a hacer un terrario de plantas tropicales en el baño',
            'Hacer un terrario de helechos en una botella de vidrio en casa',
            'Crear un terrario colgante en macetas de vidrio en casa',
            'Probar a hacer un terrario de plantas aromáticas en la cocina',
            'Hacer un terrario abierto con cactus y piedras decorativas en casa',
            'Crear un terrario de plantas miniatura en frascos de vidrio en casa',
            'Probar a hacer un terrario de suculentas en una lámpara de vidrio'
        ],
        'Plantas Aromáticas': [
            'Cultivar lavanda en macetas pequeñas en la terraza',
            'Probar a plantar menta en una maceta colgante en casa',
            'Hacer un rincón de romero en la cocina con luz natural',
            'Plantar tomillo en macetas recicladas en la ventana del salón',
            'Probar a cultivar orégano en una maceta decorativa en casa',
            'Hacer un jardín de plantas aromáticas en la terraza interior',
            'Plantar salvia en jardineras grandes en casa',
            'Probar a cultivar hierbabuena en macetas pequeñas en la cocina',
            'Hacer un jardín de albahaca en la ventana de la cocina',
            'Plantar eneldo en macetas de cerámica en casa',
            'Probar a hacer un jardín aromático con tomillo en el balcón',
            'Hacer un rincón de plantas aromáticas en macetas colgantes',
            'Plantar romero en macetas grandes en el salón',
            'Probar a cultivar cilantro en una maceta pequeña en casa',
            'Hacer un jardín vertical de plantas aromáticas en casa',
            'Plantar menta poleo en macetas decorativas en la terraza',
            'Probar a hacer un jardín de lavandas en una mesa interior',
            'Hacer un jardín aromático con hierbas frescas en la cocina',
            'Plantar hinojo en macetas recicladas en casa',
            'Probar a cultivar perejil en la ventana del salón'
        ]
    },
    'Música y Baile': {
        'Instrumentos Musicales': [
            'Practicar escalas en el piano',
            'Aprender a tocar una canción de {artista} en guitarra',
            'Probar un tutorial de batería para principiantes en Youtube',
            'Tocar una melodía sencilla en la flauta dulce en casa',
            'Aprender a afinar un violín correctamente en casa',
            'Practicar acordes básicos en ukelele con una canción popular',
            'Probar una clase de saxofón en Youtube',
            'Tocar una pieza clásica en el piano en casa',
            'Practicar arpegios en guitarra con una canción de {artista}',
            'Probar a tocar una pieza de jazz en la trompeta en casa',
            'Aprender una canción sencilla en la guitarra eléctrica en casa',
            'Tocar una pieza folk en el violín con ayuda de Youtube',
            'Probar una clase de percusión africana en casa',
            'Practicar técnicas de rasgueo en guitarra flamenca en casa',
            'Aprender a tocar una canción de rock en la batería en casa',
            'Tocar una pieza barroca en el teclado en casa',
            'Probar una clase de clarinete para principiantes en Youtube',
            'Practicar una canción de pop en el piano en casa',
            'Aprender a tocar el bajo eléctrico con una canción de iniciación',
            'Probar a tocar una balada en el saxofón en casa'
        ],
        'Composición': [
            'Escribir una canción de amor con acordes sencillos en {instrumento}',
            'Componer una melodía para piano inspirada en {tema}',
            'Probar a crear una pieza instrumental para guitarra en casa',
            'Escribir una letra para una canción de amor',
            'Componer una canción en guitarra utilizando progresiones de acordes',
            'Probar a hacer una composición con ritmos latinos en casa',
            'Escribir una canción inspirada en un viaje a {lugar}',
            'Componer una pieza para violín y piano en casa',
            'Crear una canción con un ritmo de percusión africana',
            'Escribir una canción sobre el cambio de estaciones en casa',
            'Probar a componer una balada pop en guitarra en casa',
            'Escribir una canción instrumental utilizando sintetizadores en Youtube',
            'Componer una pieza electrónica con loops en {software}',
            'Crear una canción de rock con riffs de guitarra en casa',
            'Escribir una canción para piano en estilo jazz',
            'Probar a componer una melodía de música clásica para cuerdas',
            'Escribir una canción con ritmo reggae en guitarra en casa',
            'Componer una pieza para orquesta de cámara en Youtube',
            'Crear una canción folk con una historia sobre {tema}',
            'Probar a escribir una pieza de música minimalista en piano'
        ],
        'Danza Clásica': [
            'Practicar posiciones básicas de ballet en casa frente al espejo',
            'Hacer una rutina de ballet clásico con énfasis en la técnica de pies',
            'Probar una clase de danza clásica en línea para principiantes en Youtube',
            'Practicar saltos y giros básicos de ballet en casa',
            'Hacer una coreografía clásica con música de tu artista favorito',
            'Probar una rutina de barra de ballet en casa',
            'Practicar movimientos de adagio en danza clásica en casa',
            'Hacer un calentamiento de ballet con música clásica en casa',
            'Probar una clase de ballet clásico intermedio en Youtube',
            'Practicar pasos de puntas en ballet en casa',
            'Hacer una coreografía inspirada en un ballet clásico conocido',
            'Probar una sesión de danza clásica con ejercicios de port de bras en casa',
            'Practicar los giros en pirueta con técnicas de ballet en casa',
            'Hacer una rutina de ballet de centro con música de piano en casa',
            'Probar una clase de ballet clásico para mejorar la flexibilidad',
            'Practicar ejercicios de extensión de piernas en ballet en casa',
            'Hacer una coreografía de ballet con movimientos suaves y fluidos',
            'Probar una rutina de barra de ballet clásica con ejercicios de fuerza en Youtube',
            'Practicar saltos en relevé y plié en ballet en casa',
            'Hacer una rutina de ballet clásico enfocada en el equilibrio y la postura'
        ],
        'Danza Moderna': [
            'Practicar movimientos de danza contemporánea en casa',
            'Probar una clase de danza moderna en Youtube',
            'Hacer una coreografía de danza moderna con música de {artista}',
            'Practicar movimientos de improvisación en danza moderna en casa',
            'Probar una rutina de danza moderna con énfasis en el ritmo',
            'Hacer una coreografía abstracta en danza contemporánea en casa',
            'Practicar movimientos de suelo en danza moderna en casa',
            'Probar una clase de danza moderna intermedia en Youtube',
            'Hacer una coreografía de danza contemporánea basada en {tema}',
            'Practicar técnicas de caída y recuperación en danza moderna',
            'Probar una sesión de improvisación de danza moderna en casa',
            'Hacer una coreografía de danza moderna inspirada en {tema}',
            'Practicar movimientos de danza moderna con énfasis en el espacio',
            'Probar una rutina de danza moderna con movimientos fluidos en casa',
            'Hacer una coreografía contemporánea con música instrumental en casa',
            'Practicar saltos y giros en danza moderna en casa',
            'Probar una clase avanzada de danza moderna en Youtube',
            'Hacer una rutina de danza moderna con movimientos de contacto en casa',
            'Practicar técnicas de danza moderna para mejorar la fluidez corporal',
            'Hacer una coreografía de danza contemporánea con elementos de improvisación'
        ],
        'Canto': [
            'Practicar escalas vocales en casa para mejorar el rango',
            'Probar una clase de técnica vocal en Youtube',
            'Cantar una canción de tu lista preferida de Spotify para mejorar la afinación',
            'Practicar respiración diafragmática en el canto en casa',
            'Probar una rutina vocal con ejercicios de entonación en casa',
            'Cantar una canción a capella para mejorar el control vocal',
            'Practicar ejercicios de resonancia en el canto en casa',
            'Probar una clase de canto lírico en Youtube',
            'Cantar una balada romántica para mejorar la expresión en casa',
            'Practicar técnicas de canto melódico en casa',
            'Probar una sesión de calentamiento vocal con ejercicios de proyección en casa',
            'Cantar una canción de tu artista preferido para mejorar el control del vibrato',
            'Practicar ejercicios de vocalización en casa',
            'Probar una clase de canto pop en Yousician',
            'Cantar una canción de musical en casa con técnicas teatrales',
            'Practicar técnicas de respiración para aumentar la potencia vocal',
            'Probar una sesión de canto coral en Youtube',
            'Cantar una canción de ópera para mejorar el rango vocal',
            'Practicar ejercicios de control de volumen en el canto en casa',
            'Probar una clase de canto jazz en Youtube'
        ],
        'Coreografías': [
            'Crear una coreografía sencilla con música latina',
            'Probar a coreografiar una rutina de baile moderno en casa',
            'Hacer una coreografía en grupo con amigos en casa',
            'Crear una coreografía de danza contemporánea inspirada en {tema}',
            'Probar una coreografía de baile latino en casa con música de {artista}',
            'Hacer una coreografía de hip-hop con pasos básicos en casa',
            'Probar una rutina coreografiada de zumba en Youtube',
            'Crear una coreografía de jazz para una canción de {artista}',
            'Hacer una coreografía de street dance con movimientos rápidos en casa',
            'Probar una sesión de coreografía inspirada en el flamenco en casa',
            'Crear una coreografía de baile en pareja con música de {artista}',
            'Hacer una rutina de baile coreografiado con elementos de salsa en casa',
            'Probar una coreografía de música disco en casa',
            'Crear una coreografía de baile clásico con movimientos fluidos en casa',
            'Hacer una coreografía grupal para un evento familiar en casa',
            'Probar una rutina coreografiada de baile de los 90 en Youtube',
            'Crear una coreografía de danza moderna inspirada en {tema}',
            'Hacer una coreografía de baile urbano con movimientos creativos en casa',
            'Probar una coreografía de Bollywood con música alegre en casa',
            'Crear una coreografía de ballet contemporáneo para una canción de {artista}'
        ],
        'Improvisación': [
            'Probar una sesión de improvisación musical con el piano en casa',
            'Hacer una sesión de improvisación de guitarra en casa',
            'Improvisar un solo de batería inspirado en rock&roll',
            'Probar una sesión de improvisación vocal en casa con música de {artista}',
            'Hacer una improvisación en violín con melodías libres en casa',
            'Improvisar una pieza de jazz en el saxofón en casa',
            'Probar una sesión de improvisación de danza moderna en casa',
            'Improvisar una canción en guitarra con acordes sencillos',
            'Hacer una sesión de improvisación de percusión con objetos de casa',
            'Probar una improvisación melódica con escalas pentatónicas en {instrumento}',
            'Improvisar una coreografía de danza contemporánea con música instrumental',
            'Hacer una improvisación musical con loops en Youtube',
            'Probar una sesión de improvisación de rap en casa',
            'Improvisar un solo de guitarra eléctrica en casa',
            'Hacer una improvisación de canto con variaciones melódicas en casa',
            'Probar una sesión de improvisación de percusión africana en casa',
            'Improvisar una pieza musical inspirada en el ambiente de {lugar}',
            'Hacer una sesión de improvisación vocal a capella en casa',
            'Probar una improvisación rítmica con instrumentos de percusión en casa',
            'Improvisar una danza contemporánea con música ambiental en casa'
        ],
        'Percusión': [
            'Practicar ritmos básicos de percusión con baquetas en casa',
            'Probar a tocar un tambor africano en casa',
            'Hacer una sesión de percusión con un cajón flamenco en casa',
            'Probar una clase de percusión con congas en Youtube',
            'Practicar patrones rítmicos en un set de batería en casa',
            'Tocar una melodía sencilla en un xilófono en casa',
            'Probar una clase de percusión latina en línea',
            'Hacer una sesión de percusión corporal con ritmos africanos',
            'Probar a tocar una darbuka con ritmos árabes en casa',
            'Practicar patrones de ritmo en un tambor metálico en casa',
            'Hacer una sesión de percusión de samba con instrumentos caseros',
            'Probar una clase de bongo en línea para principiantes en Youtube',
            'Practicar ritmos complejos en la batería con música de cine',
            'Hacer una sesión de percusión con cucharas y objetos caseros en casa',
            'Probar a tocar el djembe en una clase en línea',
            'Practicar ritmos caribeños en un set de timbales en casa',
            'Hacer una sesión de percusión con tambores de mano en casa',
            'Probar una clase de percusión japonesa taiko en Youtube',
            'Practicar ritmos folclóricos en un pandero en casa',
            'Hacer una sesión de percusión con bongos en un grupo de amigos en casa'
        ],
        'Ritmos del Mundo': [
            'Probar una clase de ritmos africanos en Youtube',
            'Hacer una sesión de baile con ritmos latinos en casa',
            'Practicar percusión con ritmos flamencos en casa',
            'Probar una clase de ritmos brasileños en casa',
            'Hacer una coreografía con ritmos árabes en casa',
            'Practicar pasos de baile con ritmos de salsa en casa',
            'Probar una sesión de percusión con ritmos caribeños en Spotify',
            'Hacer una coreografía de danza india con ritmos bollywood en casa',
            'Probar una sesión de baile con ritmos afro-cubanos en casa',
            'Practicar ritmos celtas en percusión en casa',
            'Hacer una rutina de baile con ritmos reggaeton en casa',
            'Probar una clase de percusión con ritmos de samba en Youtube',
            'Practicar pasos de baile con ritmos de merengue en casa',
            'Hacer una sesión de danza con ritmos africanos en casa',
            'Probar una clase de ritmos electrónicos con tambores digitales en Youtube',
            'Practicar ritmos folclóricos en una clase de percusión en casa',
            'Hacer una coreografía de salsa con música cubana en casa',
            'Probar una clase de percusión con ritmos hawaianos en Youtube',
            'Practicar ritmos de tango con percusión en casa',
            'Hacer una rutina de danza con ritmos de bachata en casa'
        ],
        'Expresión Corporal': [
            'Probar una sesión de expresión corporal con música instrumental en casa',
            'Hacer una sesión de movimientos libres en casa',
            'Practicar técnicas de contacto en expresión corporal con un compañero',
            'Probar una clase de expresión corporal para mejorar la fluidez en Youtube',
            'Hacer una improvisación de expresión corporal basada en emociones',
            'Practicar movimientos de estiramiento y expansión en casa',
            'Probar una sesión de expresión corporal con elementos teatrales en casa',
            'Hacer una rutina de expresión corporal con música clásica en casa',
            'Practicar técnicas de improvisación en expresión corporal en casa',
            'Probar una clase de expresión corporal con música contemporánea en Youtube',
            'Hacer una sesión de contacto e improvisación en expresión corporal en casa',
            'Practicar movimientos de expresión corporal basados en la respiración en casa',
            'Probar una sesión de expresión corporal inspirada en la naturaleza en Youtube',
            'Hacer una rutina de expresión corporal con movimientos fluidos en casa',
            'Practicar técnicas de expresión corporal para mejorar la conciencia espacial',
            'Probar una clase de expresión corporal con elementos de danza moderna',
            'Hacer una sesión de improvisación de movimientos suaves en casa',
            'Practicar ejercicios de expresión corporal con objetos en casa',
            'Probar una rutina de expresión corporal con movimientos de torsión en Youtube',
            'Hacer una sesión de expresión corporal inspirada en {tema}'
        ]
    },
    'Lectura y Escritura Creativa': {
        'Lectura de Ficción': [
            'Leer una novela de ciencia ficción de {autor} en casa',
            'Sumergirse en una saga de fantasía épica',
            'Leer un libro de misterio y suspenso de {autor} en casa',
            'Disfrutar de una novela romántica ambientada en {lugar}',
            'Leer una novela histórica basada en hechos reales de {época}',
            'Sumergirse en una novela de terror escrita por {autor}',
            'Leer una novela de aventuras en un mundo ficticio en casa',
            'Disfrutar de una obra de ficción especulativa en casa',
            'Leer un cuento corto de realismo mágico de {autor}',
            'Sumergirse en una novela de detectives en casa',
            'Leer un libro de ficción contemporánea sobre {tema}',
            'Disfrutar de una historia de fantasía urbana en casa',
            'Leer una novela de drama familiar con personajes complejos',
            'Sumergirse en una novela de ciencia ficción distópica en casa',
            'Leer un libro de fantasía oscura lleno de criaturas míticas',
            'Disfrutar de una novela juvenil de aventuras en casa',
            'Leer un relato corto de ficción gótica en casa',
            'Sumergirse en una novela policíaca con intriga y giros en casa',
            'Leer una historia de amor en tiempos de guerra en casa',
            'Disfrutar de una obra de ficción filosófica sobre {tema}'
        ],
        'Escritura de Narrativa': [
            'Escribir el primer capítulo de una novela de ciencia-ficción en casa',
            'Crear una historia corta sobre un misterio en casa',
            'Escribir una novela de ciencia ficción ambientada en {lugar}',
            'Probar a escribir una historia de aventuras con personajes intrépidos',
            'Escribir una narración desde el punto de vista de un villano en casa',
            'Crear una historia basada en una leyenda urbana de {lugar}',
            'Escribir una novela histórica ambientada en {época} en casa',
            'Probar a escribir un cuento de realismo mágico en casa',
            'Escribir una historia de terror con un final sorprendente en casa',
            'Crear una historia de amor prohibido en tiempos difíciles en casa',
            'Escribir una historia de detectives con pistas ocultas en casa',
            'Probar a escribir una historia corta con un giro inesperado en casa',
            'Escribir una novela juvenil sobre un grupo de amigos en {lugar}',
            'Crear una narración sobre una distopía futurista en casa',
            'Escribir una historia basada en una carta perdida en casa',
            'Probar a escribir una historia de fantasía con criaturas míticas en casa',
            'Escribir un cuento corto sobre una amistad improbable en casa',
            'Crear una historia de ciencia ficción con elementos steampunk en casa',
            'Escribir una historia de viajes en el tiempo y sus consecuencias en casa',
            'Probar a escribir una novela sobre una conspiración global en casa'
        ],
        'Poesía': [
            'Escribir un poema sobre la naturaleza en casa',
            'Crear un poema inspirado en un paisaje urbano en casa',
            'Escribir un soneto dedicado al amor imposible en casa',
            'Probar a escribir un poema haiku sobre la primavera en casa',
            'Escribir un poema sobre los recuerdos de la infancia en casa',
            'Crear una poesía libre sobre el paso del tiempo en casa',
            'Escribir un poema narrativo sobre una leyenda antigua en casa',
            'Probar a escribir un poema de estilo surrealista en casa',
            'Escribir un poema que rime sobre los sentimientos encontrados en casa',
            'Crear una poesía breve sobre la soledad en casa',
            'Escribir un poema sobre la lluvia y su significado en casa',
            'Probar a escribir un poema de estilo gótico en casa',
            'Escribir un poema épico inspirado en héroes de la antigüedad en casa',
            'Crear un poema sobre la transformación personal en casa',
            'Escribir un poema de amor con metáforas sobre el mar en casa',
            'Probar a escribir una oda a la libertad en casa',
            'Escribir un poema sobre el ciclo de la vida en casa',
            'Crear un poema con imágenes sensoriales sobre el verano en casa',
            'Escribir un poema sobre los sueños y su poder en casa',
            'Probar a escribir un poema lírico sobre la nostalgia en casa'
        ],
        'Diario Personal': [
            'Escribir sobre los momentos importantes del día en casa',
            'Hacer una reflexión personal sobre las metas futuras en casa',
            'Escribir un diario sobre los sentimientos encontrados en casa',
            'Anotar las pequeñas victorias del día en tu diario en casa',
            'Escribir un diario sobre los cambios en la vida diaria en casa',
            'Hacer una entrada de diario sobre los sueños recientes en casa',
            'Escribir sobre un momento de superación personal en casa',
            'Reflexionar en el diario sobre los desafíos enfrentados durante el mes en casa',
            'Anotar en tu diario los pensamientos positivos del día en casa',
            'Escribir sobre los logros de la semana en casa',
            'Hacer una entrada de diario sobre los nuevos proyectos en mente en casa',
            'Escribir sobre las emociones experimentadas hoy en casa',
            'Anotar en el diario los recuerdos de la infancia en casa',
            'Reflexionar sobre el crecimiento personal en casa',
            'Escribir en el diario sobre las relaciones importantes en casa',
            'Hacer una entrada de diario sobre los momentos de gratitud en casa',
            'Escribir sobre los sueños que aún quieres alcanzar en casa',
            'Anotar los aprendizajes de la semana en el diario en casa',
            'Reflexionar sobre un cambio reciente en la vida en casa',
            'Escribir sobre tus planes a largo plazo en el diario en casa'
        ],
        'Guiones': [
            'Escribir el guion de un cortometraje de suspense en casa',
            'Probar a escribir un guion para una serie de ciencia ficción en casa',
            'Escribir el diálogo de una escena dramática entre dos personajes en casa',
            'Crear el guion de un monólogo sobre la vida en casa',
            'Escribir una escena de acción para una película en casa',
            'Probar a escribir un guion para una obra de teatro en casa',
            'Escribir una escena de comedia romántica con diálogos ingeniosos en casa',
            'Crear un guion para un thriller psicológico en casa',
            'Escribir el guion de una escena de confrontación entre dos personajes en casa',
            'Probar a crear un guion de animación para una historia fantástica en casa',
            'Escribir el guion de una película de época en casa',
            'Crear un guion para un episodio piloto de una serie dramática en casa',
            'Escribir una escena de terror psicológico en casa',
            'Probar a escribir un guion de ciencia ficción futurista en casa',
            'Escribir el guion de una comedia situacional para televisión en casa',
            'Crear un guion para una escena de intriga política en casa',
            'Escribir una escena de aventuras para una película familiar en casa',
            'Probar a escribir un guion de fantasía épica en casa',
            'Escribir una escena romántica con un giro inesperado en casa',
            'Crear el guion de un documental sobre {tema} en casa'
        ],
        'Análisis de Lecturas': [
            'Escribir un análisis sobre el uso de la simbología en tu novela preferida',
            'Analizar el desarrollo del protagonista en una novela de {autor}',
            'Hacer una reseña crítica de una obra clásica de {autor}',
            'Escribir sobre los temas principales en una novela de guerra',
            'Probar a analizar la estructura narrativa de un cuento de {autor}',
            'Escribir un análisis sobre el papel de la mujer en una novela antigua',
            'Hacer una reseña comparativa entre dos libros de {autor}',
            'Analizar el contexto histórico de una obra ambientada en {época}',
            'Escribir un ensayo sobre los arquetipos en {autor}',
            'Probar a analizar el estilo literario de una novela de Edgar Allan Poe',
            'Escribir sobre el uso de los diálogos en una novela de {autor}',
            'Hacer un análisis sobre el simbolismo de los sueños que tuviste anoche',
            'Escribir una crítica sobre la influencia de la política en una novela que te guste',
            'Probar a analizar la evolución de los personajes en una saga de {autor}',
            'Escribir un ensayo sobre los temas filosóficos en alguna obra que tengas en casa',
            'Hacer un análisis del lenguaje poético en {colección de poemas}',
            'Escribir una reseña sobre el realismo mágico en la obra de {autor}',
            'Probar a analizar el conflicto central en una novela policíaca',
            'Escribir un ensayo sobre el uso de las metáforas en alguna obra que tengas en casa',
            'Hacer un análisis sobre los temas recurrentes en la obra de {autor}'
        ],
        'Relatos de Viajes': [
            'Escribir un relato sobre un viaje a {lugar} lleno de aventuras',
            'Crear una narración sobre una expedición al desierto de {lugar}',
            'Escribir sobre un viaje inolvidable a una ciudad costera en casa',
            'Probar a escribir un relato sobre un viaje en tren a través de {lugar}',
            'Escribir una historia sobre un viaje en barco por {río o mar}',
            'Crear un relato sobre una travesía por la selva de {país} en casa',
            'Escribir sobre un viaje a una isla remota en casa',
            'Probar a crear un relato sobre una aventura en las montañas de {lugar}',
            'Escribir una historia de un viaje en solitario por {país} en casa',
            'Crear un relato sobre un viaje en bicicleta por la campiña de {lugar}',
            'Escribir sobre un viaje improvisado a una ciudad desconocida en casa',
            'Probar a narrar un viaje en caravana por {lugar} en casa',
            'Escribir sobre un recorrido en tren por Europa en casa',
            'Crear una historia sobre una ruta de senderismo por los Andes en casa',
            'Escribir un relato sobre un viaje espiritual a donde quieras en casa',
            'Probar a escribir una historia de un viaje en globo sobre {lugar}',
            'Escribir sobre un viaje en coche por la costa de {lugar} en casa',
            'Crear un relato sobre una aventura en un safari por {país} en casa',
            'Escribir sobre un viaje de mochilero por Asia en casa',
            'Probar a narrar un viaje en tren por el Ártico en casa'
        ],
        'Creación de Personajes': [
            'Escribir una descripción detallada de un personaje heroico en casa',
            'Probar a crear un personaje basado en una persona de la vida real en casa',
            'Escribir una biografía ficticia para un villano con un pasado oscuro en casa',
            'Crear un personaje secundario con un secreto importante en casa',
            'Escribir sobre un personaje con habilidades mágicas en casa',
            'Probar a desarrollar un personaje cómico con rasgos exagerados en casa',
            'Crear un personaje inspirado en un mito antiguo en casa',
            'Escribir una historia corta centrada en un personaje con un dilema moral en casa',
            'Probar a crear un personaje basado en un animal antropomorfizado en casa',
            'Escribir sobre un personaje rebelde en un mundo distópico en casa',
            'Crear un personaje con una habilidad especial que debe ocultar en casa',
            'Probar a desarrollar un personaje que cambia de identidad en casa',
            'Escribir sobre un personaje con un objetivo imposible de alcanzar en casa',
            'Crear un personaje basado en una figura histórica en casa',
            'Probar a escribir una historia centrada en un personaje antihéroe en casa',
            'Escribir sobre un personaje que ha perdido todo y debe comenzar de nuevo en casa',
            'Crear un personaje que lucha por superar su pasado en casa',
            'Probar a crear un personaje con un doble propósito en casa',
            'Escribir sobre un personaje que esconde su verdadera identidad en casa',
            'Crear un personaje que debe enfrentarse a una profecía en casa'
        ],
        'Ensayos': [
            'Escribir un ensayo sobre la influencia de la tecnología en la vida moderna en casa',
            'Probar a escribir un ensayo crítico sobre el cambio climático en casa',
            'Escribir un ensayo sobre el impacto de las redes sociales en la comunicación en casa',
            'Hacer un ensayo sobre la importancia de la educación en casa',
            'Escribir un ensayo argumentativo sobre los derechos humanos en casa',
            'Probar a escribir un ensayo sobre la globalización y su impacto en la cultura en casa',
            'Escribir un ensayo personal sobre la superación de desafíos en casa',
            'Hacer un ensayo sobre la importancia de la libertad de expresión en casa',
            'Probar a escribir un ensayo comparativo sobre dos obras literarias en casa',
            'Escribir un ensayo crítico sobre los medios de comunicación en casa',
            'Hacer un ensayo sobre los avances científicos y su impacto en la sociedad en casa',
            'Escribir un ensayo reflexivo sobre la inteligencia artificial y el futuro en casa',
            'Probar a escribir un ensayo sobre la igualdad de género en casa',
            'Escribir un ensayo filosófico sobre el sentido de la vida en casa',
            'Hacer un ensayo sobre el papel de la literatura en el cambio social en casa',
            'Probar a escribir un ensayo crítico sobre la censura en los medios en casa',
            'Escribir un ensayo sobre la evolución del arte contemporáneo en casa',
            'Hacer un ensayo sobre el impacto de la tecnología en la educación en casa',
            'Probar a escribir un ensayo comparativo sobre dos movimientos artísticos en casa',
            'Escribir un ensayo sobre el papel de la política en el cambio climático en casa'
        ],
        'Cartas y Correspondencia': [
            'Escribir una carta a un amigo lejano sobre los recuerdos compartidos en casa',
            'Probar a redactar una carta formal de agradecimiento en casa',
            'Escribir una carta de amor imaginaria a un personaje de Netflix',
            'Hacer una carta de disculpa sincera a alguien en casa',
            'Probar a redactar una carta abierta sobre un tema social importante en casa',
            'Escribir una carta de felicitación por un logro especial en casa',
            'Hacer una carta a un ser querido que ya no está en casa',
            'Probar a redactar una carta de motivación para un nuevo proyecto en casa',
            'Escribir una carta ficticia entre dos personajes históricos en casa',
            'Hacer una carta personal contando las emociones del último año en casa',
            'Probar a redactar una carta de despedida a un amigo en casa',
            'Escribir una carta de agradecimiento por una lección aprendida en casa',
            'Hacer una carta formal solicitando un puesto de trabajo en casa',
            'Probar a redactar una carta de presentación creativa para un proyecto en casa',
            'Escribir una carta dirigida a tu yo del futuro en casa',
            'Hacer una carta a un personaje literario contando tus inquietudes en casa',
            'Probar a redactar una carta de recomendación para un colega en casa',
            'Escribir una carta a un mentor agradeciendo sus consejos en casa',
            'Hacer una carta de apoyo a una persona que está pasando por un mal momento en casa',
            'Probar a redactar una carta inspiradora para ti mismo en casa'
        ]
    },
    'Cuidado Personal y Relajación': {
        'Meditación': [
                'Practicar meditación guiada con enfoque en la respiración en casa',
                'Hacer una sesión de meditación en silencio con música relajante en casa',
                'Probar una meditación de atención plena para reducir el estrés en casa',
                'Practicar una meditación con visualizaciones positivas en casa',
                'Hacer una meditación enfocada en la gratitud antes de dormir en casa',
                'Probar una meditación de escaneo corporal para relajar los músculos en casa',
                'Practicar una meditación para aumentar la concentración en casa',
                'Hacer una meditación guiada con música relajante en casa',
                'Probar una meditación de amor y bondad para cultivar emociones positivas en casa',
                'Practicar una meditación de respiración profunda al comenzar el día en casa',
                'Hacer una meditación caminando por casa para calmar la mente',
                'Probar una meditación guiada para liberar tensiones emocionales en casa',
                'Practicar una meditación de enfoque en el presente en casa',
                'Hacer una meditación de conexión con la naturaleza visualizando paisajes en casa',
                'Probar una meditación trascendental con mantras en casa',
                'Practicar una meditación con enfoque en el perdón en casa',
                'Hacer una meditación guiada para reducir la ansiedad en casa',
                'Probar una meditación de visualización creativa en casa',
                'Practicar una meditación enfocada en el equilibrio emocional en casa',
                'Hacer una meditación de relajación profunda antes de dormir en casa'
            ],
        'Terapias de Relajación': [
            'Probar una terapia de relajación con piedras calientes en casa',
            'Hacer una sesión de relajación muscular progresiva para reducir el estrés en casa',
            'Practicar una terapia de relajación con aceites esenciales en casa',
            'Probar una sesión de relajación con música ambiental en casa',
            'Hacer una terapia de relajación con aromaterapia en casa',
            'Practicar una sesión de relajación con respiración controlada en casa',
            'Probar una terapia de relajación con sonidos de la naturaleza en casa',
            'Hacer una sesión de relajación guiada para liberar tensiones en casa',
            'Practicar una terapia de relajación con estiramientos suaves en casa',
            'Probar una terapia de relajación con técnicas de masaje en casa',
            'Hacer una sesión de relajación muscular para aliviar dolores de espalda en casa',
            'Practicar una terapia de relajación con visualizaciones calmantes en casa',
            'Probar una terapia de relajación con baños de pies en casa',
            'Hacer una terapia de relajación con música binaural en casa',
            'Practicar una sesión de relajación profunda con técnicas de meditación guiada en casa',
            'Probar una terapia de relajación con almohadas térmicas en casa',
            'Hacer una sesión de relajación con técnicas de respiración diafragmática en casa',
            'Practicar una terapia de relajación con técnicas de mindfulness en casa',
            'Probar una sesión de relajación con técnicas de yoga restaurativo en casa',
            'Hacer una terapia de relajación para liberar el estrés acumulado en casa'
        ],
        'Cuidado de la Piel': [
            'Hacer una rutina de cuidado facial con mascarillas naturales en casa',
            'Probar un tratamiento de exfoliación con productos caseros en casa',
            'Aplicar una mascarilla hidratante para la piel en casa',
            'Hacer una limpieza facial profunda en casa con vapor de agua',
            'Probar una rutina de cuidado facial para piel sensible en casa',
            'Aplicar una mascarilla de arcilla para purificar la piel en casa',
            'Hacer un tratamiento casero de exfoliación con azúcar y miel en casa',
            'Probar una rutina de cuidado facial anti-envejecimiento en casa',
            'Aplicar un sérum hidratante para revitalizar la piel en casa',
            'Hacer una rutina de cuidado de la piel con productos orgánicos en casa',
            'Probar una técnica de masaje facial con rodillos de jade en casa',
            'Hacer una rutina nocturna de cuidado de la piel en casa',
            'Aplicar una mascarilla de aloe vera para calmar la piel en casa',
            'Probar una rutina de hidratación intensa para piel seca en casa',
            'Hacer un tratamiento facial con productos naturales para cerrar poros en casa',
            'Aplicar una mascarilla de vitamina C para iluminar la piel en casa',
            'Probar una rutina de cuidado facial coreano de 10 pasos en casa',
            'Hacer un masaje facial para estimular la circulación en casa',
            'Aplicar una mascarilla de pepino para refrescar la piel en casa',
            'Probar una técnica de drenaje linfático facial en casa'
        ],
        'Masajes': [
            'Hacer un masaje relajante en las piernas con aceites esenciales en casa',
            'Probar una técnica de masaje en los hombros para aliviar tensiones en casa',
            'Hacer un masaje en las manos para mejorar la circulación en casa',
            'Probar un masaje con piedras calientes para relajar la espalda en casa',
            'Hacer un masaje en los pies con un rodillo de masaje en casa',
            'Probar una técnica de masaje para aliviar el dolor de cuello en casa',
            'Hacer un masaje en la zona lumbar para reducir el estrés en casa',
            'Probar un masaje facial con aceites para revitalizar la piel en casa',
            'Hacer un masaje en los hombros y el cuello con presión moderada en casa',
            'Probar una técnica de automasaje para aliviar el cansancio en las piernas en casa',
            'Hacer un masaje relajante en los brazos con crema hidratante en casa',
            'Probar un masaje de cabeza y cuero cabelludo para aliviar el estrés en casa',
            'Hacer un masaje en los pies con aceites relajantes en casa',
            'Probar una técnica de masaje profundo para deshacer nudos musculares en casa',
            'Hacer un masaje en la espalda utilizando una pelota de tenis en casa',
            'Probar una técnica de masaje tailandés para mejorar la flexibilidad en casa',
            'Hacer un masaje en las manos con una crema nutritiva en casa',
            'Probar un masaje en los pies con reflexología para mejorar el bienestar en casa',
            'Hacer un masaje relajante en el cuello con movimientos circulares en casa',
            'Probar un masaje con aceites esenciales para aliviar la tensión muscular en casa'
        ],
        'Aromaterapia': [
            'Probar una sesión de aromaterapia con aceites esenciales de lavanda en casa',
            'Hacer una sesión de aromaterapia con velas perfumadas en casa',
            'Probar una mezcla de aceites esenciales para aliviar el estrés en casa',
            'Hacer una sesión de aromaterapia con difusores y aceites cítricos en casa',
            'Probar una combinación de aceites de romero y menta para mejorar la concentración en casa',
            'Hacer una sesión de aromaterapia con aceites relajantes antes de dormir en casa',
            'Probar una mezcla de aceites de eucalipto y árbol de té para despejar las vías respiratorias en casa',
            'Hacer una sesión de aromaterapia con aceites de rosa para equilibrar las emociones en casa',
            'Probar una combinación de aceites esenciales para mejorar el estado de ánimo en casa',
            'Hacer una sesión de aromaterapia con aceites de lavanda y manzanilla en casa',
            'Probar una mezcla de aceites para aliviar dolores musculares en casa',
            'Hacer una sesión de aromaterapia con esencias de cítricos para revitalizar el ambiente en casa',
            'Probar una mezcla de aceites esenciales de incienso y mirra para meditar en casa',
            'Hacer una sesión de aromaterapia con aceites de vainilla y sándalo para una atmósfera acogedora en casa',
            'Probar una combinación de aceites de bergamota y jazmín para reducir la ansiedad en casa',
            'Hacer una sesión de aromaterapia con aceites de coco y vainilla en casa',
            'Probar una mezcla de aceites esenciales de pino y cedro para revitalizar la energía en casa',
            'Hacer una sesión de aromaterapia con aceites de menta para estimular la mente en casa',
            'Probar una combinación de aceites de neroli y lavanda para una noche relajante en casa',
            'Hacer una sesión de aromaterapia con aceites de flor de azahar para aliviar el estrés en casa'
        ],
        'Cuidado de Manos y Pies': [
            'Hacer un baño relajante de pies con sales y aceites en casa',
            'Probar una exfoliación casera para manos suaves en casa',
            'Hacer una pedicura en casa con productos naturales en casa',
            'Probar un tratamiento de hidratación intensa para manos secas en casa',
            'Hacer una manicura sencilla en casa con esmaltes naturales',
            'Probar un masaje relajante en los pies con aceites en casa',
            'Hacer un tratamiento de uñas fortalecedor en casa con productos caseros',
            'Probar una exfoliación profunda para pies con una mezcla de sal y aceite en casa',
            'Hacer una manicura francesa en casa con herramientas básicas',
            'Probar un baño de pies con agua tibia y aceites esenciales en casa',
            'Hacer un tratamiento de parafina casera para manos en casa',
            'Probar una mascarilla hidratante para pies con ingredientes naturales en casa',
            'Hacer una sesión de cuidado de uñas en manos con limado y esmaltado en casa',
            'Probar un baño de pies con sales de Epsom para aliviar la fatiga en casa',
            'Hacer una manicura con esmalte en gel en casa',
            'Probar una rutina de cuidado intensivo para cutículas en casa',
            'Hacer un masaje relajante en las manos con crema hidratante en casa',
            'Probar un tratamiento de exfoliación y masaje en los pies en casa',
            'Hacer una pedicura completa con cuidado de cutículas en casa',
            'Probar una mascarilla casera para pies secos en casa'
        ],
        'Música Relajante': [
            'Escuchar música de piano suave para relajarse en casa',
            'Probar una lista de reproducción de sonidos de la naturaleza en casa',
            'Escuchar música ambiental con sonidos de agua en casa',
            'Probar una sesión de relajación con música clásica en casa',
            'Escuchar música de cuencos tibetanos para calmar la mente en casa',
            'Probar una sesión de relajación con música de flauta nativa en casa',
            'Escuchar sonidos relajantes de la lluvia en casa',
            'Probar una lista de reproducción de música de meditación en casa',
            'Escuchar música instrumental con sonidos de viento en casa',
            'Probar una sesión de relajación con música de arpa en casa',
            'Escuchar música de cuencos de cristal para equilibrar el cuerpo en casa',
            'Probar una lista de reproducción de música zen en casa',
            'Escuchar música ambiental con sonidos del bosque en casa',
            'Probar una sesión de relajación con música de cuerdas suaves en casa',
            'Escuchar música de piano jazz para un ambiente relajante en casa',
            'Probar una lista de reproducción de música electrónica ambiental en casa',
            'Escuchar música de guitarra acústica para relajarse en casa',
            'Probar una sesión de relajación con música étnica instrumental en casa',
            'Escuchar música ambiental de spa en casa',
            'Probar una lista de reproducción de música de yoga para relajación en casa'
        ],
        'Yoga Restaurativo': [
            'Hacer una rutina de yoga restaurativo para aliviar tensiones en casa',
            'Probar una sesión de yoga restaurativo con posturas de relajación en casa',
            'Hacer una práctica de yoga restaurativo para reducir el estrés en casa',
            'Probar una clase de yoga restaurativo con apoyos en casa',
            'Hacer una rutina de yoga restaurativo enfocada en la respiración profunda en casa',
            'Probar una sesión de yoga restaurativo con énfasis en la flexibilidad en casa',
            'Hacer una práctica de yoga restaurativo para aliviar dolores musculares en casa',
            'Probar una clase de yoga restaurativo para mejorar la postura en casa',
            'Hacer una rutina de yoga restaurativo para relajarse antes de dormir en casa',
            'Probar una sesión de yoga restaurativo con música relajante en casa',
            'Hacer una práctica de yoga restaurativo para liberar tensiones emocionales en casa',
            'Probar una clase de yoga restaurativo con enfoque en la apertura de caderas en casa',
            'Hacer una rutina de yoga restaurativo para fortalecer el cuerpo y la mente en casa',
            'Probar una sesión de yoga restaurativo con movimientos suaves en casa',
            'Hacer una práctica de yoga restaurativo para aliviar el cansancio en casa',
            'Probar una clase de yoga restaurativo con énfasis en la relajación total en casa',
            'Hacer una rutina de yoga restaurativo para estirar la espalda en casa',
            'Probar una sesión de yoga restaurativo con posturas de meditación en casa',
            'Hacer una práctica de yoga restaurativo para relajar el cuello y los hombros en casa',
            'Probar una clase de yoga restaurativo con apoyo de cojines en casa'
        ],
        'Baños Relajantes': [
            'Hacer un baño relajante con sales de baño en casa',
            'Probar un baño de burbujas con aceites esenciales en casa',
            'Hacer un baño relajante con velas aromáticas en casa',
            'Probar un baño caliente con infusión de hierbas relajantes en casa',
            'Hacer un baño de pies con agua tibia y sales de baño en casa',
            'Probar un baño de vapor facial para relajar los músculos en casa',
            'Hacer un baño con aceites esenciales de lavanda en casa',
            'Probar un baño relajante con pétalos de flores en casa',
            'Hacer un baño de inmersión con música relajante en casa',
            'Probar un baño de leche y miel para suavizar la piel en casa',
            'Hacer un baño de pies con agua caliente y aceites calmantes en casa',
            'Probar un baño caliente con aceites cítricos para revitalizarse en casa',
            'Hacer un baño de sal marina para eliminar toxinas en casa',
            'Probar un baño con infusión de té verde para relajar el cuerpo en casa',
            'Hacer un baño de vapor en el rostro para abrir los poros en casa',
            'Probar un baño de pies con infusión de menta para refrescarse en casa',
            'Hacer un baño relajante con aceites de eucalipto en casa',
            'Probar un baño caliente con aceites de romero para relajar los músculos en casa',
            'Hacer un baño de inmersión con música suave en casa',
            'Probar un baño con aceites esenciales de jazmín para relajarse en casa'
        ],
        'Rutinas de Autocuidado': [
            'Hacer una rutina de autocuidado para el cabello con mascarillas naturales en casa',
            'Probar una rutina de autocuidado para la piel con exfoliantes caseros en casa',
            'Hacer una rutina de autocuidado semanal con baños relajantes en casa',
            'Probar una rutina de autocuidado para el cuerpo con aceites hidratantes en casa',
            'Hacer una rutina de autocuidado mental con meditación diaria en casa',
            'Probar una rutina de cuidado personal con productos naturales para el rostro en casa',
            'Hacer una rutina de autocuidado con baños de vapor y aromaterapia en casa',
            'Probar una rutina de autocuidado con ejercicios de respiración para el bienestar en casa',
            'Hacer una rutina de autocuidado físico con estiramientos suaves en casa',
            'Probar una rutina de autocuidado de las manos y pies con exfoliación en casa',
            'Hacer una rutina de autocuidado facial con mascarillas revitalizantes en casa',
            'Probar una rutina de autocuidado para el cabello con aceites nutritivos en casa',
            'Hacer una rutina de autocuidado mental con lecturas inspiradoras en casa',
            'Probar una rutina de autocuidado corporal con cremas hidratantes naturales en casa',
            'Hacer una rutina de autocuidado nocturno con técnicas de relajación en casa',
            'Probar una rutina de autocuidado para la piel con productos orgánicos en casa',
            'Hacer una rutina de autocuidado diario con pequeños momentos de relajación en casa',
            'Probar una rutina de autocuidado emocional con ejercicios de gratitud en casa',
            'Hacer una rutina de autocuidado para el rostro con productos calmantes en casa',
            'Probar una rutina de autocuidado físico con yoga restaurativo en casa'
        ]
    },
    'Proyectos DIY (Hazlo Tú Mismo)': {
        'Restauración': [
            'Restaurar una mesa de madera antigua con barniz en casa',
            'Probar a lijar y pintar una silla vieja en casa',
            'Restaurar una cómoda de estilo vintage con una capa de pintura en casa',
            'Hacer un proyecto de restauración de una estantería en casa',
            'Probar a arreglar un espejo antiguo con un marco nuevo en casa',
            'Restaurar una lámpara de pie aplicando una nueva pintura en casa',
            'Hacer un proyecto de restauración de una mesita de noche en casa',
            'Probar a restaurar una puerta de madera con una capa de barniz en casa',
            'Restaurar una silla de madera aplicando una técnica de decapado en casa',
            'Hacer un proyecto de restauración de un banco de jardín en casa',
            'Probar a restaurar una mesa de comedor con un acabado envejecido en casa',
            'Restaurar un marco de fotos antiguo con pintura dorada en casa',
            'Hacer un proyecto de restauración de un armario de cocina en casa',
            'Probar a restaurar una silla de mimbre con barniz en casa',
            'Restaurar una cómoda vieja aplicando una técnica de pátina en casa',
            'Hacer un proyecto de restauración de una puerta de entrada en casa',
            'Probar a restaurar un escritorio antiguo en casa',
            'Restaurar un mueble de madera con pintura chalk paint en casa',
            'Hacer un proyecto de restauración de una estantería de libros en casa',
            'Probar a restaurar una mesita de noche aplicando técnicas de decoupage en casa'
        ],
        'Decoración del Hogar': [
            'Hacer una guirnalda de papel decorativa para el salón en casa',
            'Probar a decorar una pared con fotos enmarcadas en casa',
            'Hacer un proyecto de decoración con plantas colgantes en casa',
            'Probar a hacer cojines decorativos personalizados en casa',
            'Hacer una lámpara colgante DIY para la sala de estar en casa',
            'Probar a hacer una decoración de pared con cintas y telas en casa',
            'Hacer un centro de mesa con flores secas para el comedor en casa',
            'Probar a crear cuadros decorativos con marcos reciclados en casa',
            'Hacer un proyecto de decoración con luces LED en casa',
            'Probar a hacer un reloj de pared personalizado en casa',
            'Hacer una maceta decorativa con materiales reciclados para el balcón en casa',
            'Probar a hacer una cortina decorativa con cuentas en casa',
            'Hacer una decoración de pared con figuras geométricas en casa',
            'Probar a hacer un collage de fotos familiares en casa',
            'Hacer un organizador de pared con madera y cuerdas en casa',
            'Probar a hacer un espejo decorativo con marco personalizado en casa',
            'Hacer una lámpara de mesa con materiales reciclados en casa',
            'Probar a hacer una decoración de pared con espejos pequeños en casa',
            'Hacer un mural decorativo con pintura acrílica en casa',
            'Probar a hacer una estantería flotante DIY en casa'
        ],
        'Reciclaje Creativo': [
            'Hacer una lámpara con botellas recicladas en casa',
            'Probar a crear macetas con latas recicladas en casa',
            'Hacer un organizador de escritorio con cartones reciclados en casa',
            'Probar a hacer un jarrón con botellas de vidrio recicladas en casa',
            'Hacer un estante flotante con cajas de madera recicladas en casa',
            'Probar a hacer un perchero con ramas recicladas en casa',
            'Hacer una caja organizadora con cartón reciclado en casa',
            'Probar a crear decoraciones navideñas con papel reciclado en casa',
            'Hacer un espejo decorativo con cucharas de plástico recicladas en casa',
            'Probar a hacer una lámpara de mesa con botellas recicladas en casa',
            'Hacer una cesta de almacenamiento con revistas recicladas en casa',
            'Probar a hacer una bandeja decorativa con cartón reciclado en casa',
            'Hacer una maceta colgante con botellas de plástico recicladas en casa',
            'Probar a hacer una lámpara colgante con vasos reciclados en casa',
            'Hacer una decoración de jardín con ruedas recicladas en casa',
            'Probar a hacer una mesa auxiliar con palets reciclados en casa',
            'Hacer un organizador de cocina con frascos reciclados en casa',
            'Probar a hacer un cuadro decorativo con tapones reciclados en casa',
            'Hacer una lámpara de techo con tubos de cartón reciclados en casa',
            'Probar a hacer un organizador de cables con rollos de papel reciclados en casa'
        ],
        'Tapicería': [
            'Tapizar una silla antigua con tela nueva en casa',
            'Probar a tapizar un sofá con un estilo moderno en casa',
            'Hacer un cojín decorativo con tela reciclada en casa',
            'Probar a tapizar una banqueta con una tela de colores vivos en casa',
            'Hacer una cabecera de cama tapizada con tela acolchada en casa',
            'Probar a tapizar una silla de oficina en casa',
            'Hacer un proyecto de tapicería para un taburete en casa',
            'Probar a tapizar una silla de comedor con tela estampada en casa',
            'Hacer un cojín de suelo con retales de tela en casa',
            'Probar a tapizar una otomana con una tela suave en casa',
            'Hacer una funda para una silla con tela reciclada en casa',
            'Probar a tapizar una silla de estilo retro en casa',
            'Hacer un proyecto de tapicería para un banco de jardín en casa',
            'Probar a hacer un cojín acolchado con una funda de tela en casa',
            'Tapizar un sillón antiguo para darle un nuevo aspecto en casa',
            'Hacer una funda para el reposabrazos de un sofá en casa',
            'Probar a tapizar una silla de bar en casa',
            'Hacer una colchoneta para exteriores con tela impermeable en casa',
            'Probar a tapizar un taburete con una tela a rayas en casa',
            'Hacer una funda de cojín para una silla de jardín en casa'
        ],
        'Pintura Decorativa': [
            'Pintar una pared de acento con un diseño geométrico en casa',
            'Probar a hacer un mural decorativo con pintura acrílica en casa',
            'Pintar un mueble viejo con pintura chalk paint en casa',
            'Hacer un proyecto de pintura decorativa en macetas de cerámica en casa',
            'Probar a hacer una pintura abstracta en lienzo para la sala de estar en casa',
            'Pintar un espejo con un marco decorativo de colores vivos en casa',
            'Hacer un diseño con pintura de pizarra en una pared en casa',
            'Probar a hacer un cuadro decorativo con técnica de salpicado en casa',
            'Pintar una estantería con un estilo vintage en casa',
            'Hacer un proyecto de pintura decorativa en una puerta en casa',
            'Probar a decorar una lámpara con pintura de colores en casa',
            'Pintar una maceta de barro con un diseño personalizado en casa',
            'Hacer un proyecto de pintura en un reloj de pared en casa',
            'Probar a hacer una técnica de degradado en una pared en casa',
            'Pintar un cabecero de cama con pintura decorativa en casa',
            'Hacer un diseño floral con pintura en una silla de madera en casa',
            'Probar a pintar una bandeja de madera con motivos geométricos en casa',
            'Pintar una caja de almacenamiento con un diseño moderno en casa',
            'Hacer un proyecto de pintura en un marco de fotos en casa',
            'Probar a decorar una mesa auxiliar con pintura dorada en casa'
        ],
        'Carpintería Básica': [
            'Construir una estantería de madera para libros en casa',
            'Probar a hacer una mesa auxiliar con tablas recicladas en casa',
            'Hacer un banco de madera para el jardín en casa',
            'Probar a construir un marco de fotos con madera reciclada en casa',
            'Hacer una caja organizadora con tablas de madera en casa',
            'Probar a hacer una mesa de centro con madera de palets en casa',
            'Construir una estantería flotante con madera en casa',
            'Hacer una mesa plegable de madera para el balcón en casa',
            'Probar a hacer un perchero de pared con madera reciclada en casa',
            'Construir un banco de entrada con compartimentos de almacenamiento en casa',
            'Hacer una caja de herramientas de madera en casa',
            'Probar a hacer una lámpara de mesa con una base de madera en casa',
            'Construir una jardinera de madera para el patio en casa',
            'Hacer una bandeja decorativa con madera y asas de cuerda en casa',
            'Probar a hacer un organizador de escritorio con madera en casa',
            'Construir una mesa de trabajo de madera en casa',
            'Hacer un organizador de cables de madera en casa',
            'Probar a hacer un revistero de madera para el salón en casa',
            'Construir un cabecero de cama con tablas de madera en casa',
            'Hacer una tabla para cortar con madera reciclada en casa'
        ],
        'Objetos de Almacenamiento': [
            'Hacer una caja organizadora para el escritorio con madera en casa',
            'Probar a hacer un estante flotante para libros en casa',
            'Hacer un organizador de pared con compartimentos en casa',
            'Probar a hacer una cesta de almacenamiento con cuerdas en casa',
            'Hacer un organizador de utensilios de cocina con frascos reciclados en casa',
            'Probar a hacer un organizador de maquillaje con cartón reciclado en casa',
            'Hacer una caja organizadora para cables con madera en casa',
            'Probar a hacer un organizador de cartas con materiales reciclados en casa',
            'Hacer una estantería para zapatos con madera en casa',
            'Probar a hacer un organizador de llaves con ganchos en casa',
            'Hacer un organizador de joyas con marcos reciclados en casa',
            'Probar a hacer un carrito de almacenamiento con ruedas en casa',
            'Hacer una caja organizadora para herramientas con madera en casa',
            'Probar a hacer un estante para plantas con tablas recicladas en casa',
            'Hacer un organizador de papeles con cartón reciclado en casa',
            'Probar a hacer una caja de almacenamiento para juguetes en casa',
            'Hacer un organizador de escritorio con frascos reciclados en casa',
            'Probar a hacer una estantería modular con madera en casa',
            'Hacer una caja organizadora para fotografías con cartón reciclado en casa',
            'Probar a hacer un organizador de zapatos con cartón reciclado en casa'
        ],
        'Manualidades Funcionales': [
            'Hacer un organizador de cables con tubos de cartón en casa',
            'Probar a hacer una bolsa de tela para la compra en casa',
            'Hacer un colgador de llaves con madera y ganchos en casa',
            'Probar a hacer un posavasos de corcho reciclado en casa',
            'Hacer un organizador de escritorio con cartón reciclado en casa',
            'Probar a hacer un soporte para el móvil con palitos de helado en casa',
            'Hacer un estante flotante con madera reciclada en casa',
            'Probar a hacer un portarretratos con ramas de árboles en casa',
            'Hacer una alfombrilla para el baño con tapetes reciclados en casa',
            'Probar a hacer una bolsa para llevar libros hecha a mano en casa',
            'Hacer un organizador de utensilios de cocina con latas recicladas en casa',
            'Probar a hacer un soporte para auriculares con madera en casa',
            'Hacer un estante organizador de baño con tablas de madera en casa',
            'Probar a hacer una cesta de almacenamiento con ropa reciclada en casa',
            'Hacer un colgador de toallas con tubos de PVC en casa',
            'Probar a hacer un estante para plantas con madera reciclada en casa',
            'Hacer un revistero de madera para la sala de estar en casa',
            'Probar a hacer una lámpara de escritorio con tubos de cobre en casa',
            'Hacer una caja de almacenamiento para zapatos con cartón reciclado en casa',
            'Probar a hacer un colgador para bolsos con ganchos en casa'
        ],
        'Decoración de Paredes': [
            'Hacer un mural de pared con cinta adhesiva y pintura en casa',
            'Probar a hacer un collage de fotos familiares en casa',
            'Hacer un organizador de pared con ganchos y madera en casa',
            'Probar a decorar una pared con marcos de fotos en casa',
            'Hacer una decoración de pared con cuadros reciclados en casa',
            'Probar a hacer un diseño geométrico con pintura en una pared en casa',
            'Hacer un proyecto de decoración de pared con macetas colgantes en casa',
            'Probar a hacer un mural decorativo con plantillas en casa',
            'Hacer una decoración de pared con espejos pequeños en casa',
            'Probar a hacer una decoración de pared con luces LED en casa',
            'Hacer un proyecto de decoración de pared con vinilos decorativos en casa',
            'Probar a hacer un mural de pared con fotografías en casa',
            'Hacer una decoración de pared con pinturas abstractas en casa',
            'Probar a hacer un organizador de pared con estantes en casa',
            'Hacer una decoración de pared con plantas artificiales en casa',
            'Probar a hacer una decoración de pared con cuerda y clavos en casa',
            'Hacer una decoración de pared con figuras geométricas en casa',
            'Probar a hacer una decoración de pared con papel reciclado en casa',
            'Hacer un proyecto de decoración de pared con marcos antiguos en casa',
            'Probar a hacer una decoración de pared con cintas de colores en casa'
        ],
        'Creación de Iluminación': [
            'Hacer una lámpara colgante con botellas recicladas en casa',
            'Probar a hacer una lámpara de mesa con madera reciclada en casa',
            'Hacer una lámpara de pie con tubos de cobre en casa',
            'Probar a hacer una lámpara de techo con materiales reciclados en casa',
            'Hacer una lámpara de noche con frascos de vidrio en casa',
            'Probar a hacer una lámpara colgante con cuerdas y bombillas en casa',
            'Hacer una lámpara de escritorio con un diseño minimalista en casa',
            'Probar a hacer una lámpara de pared con madera en casa',
            'Hacer una lámpara colgante con telas recicladas en casa',
            'Probar a hacer una lámpara de noche con latas recicladas en casa',
            'Hacer una lámpara de pie con una base de madera en casa',
            'Probar a hacer una lámpara de mesa con botellas de vidrio en casa',
            'Hacer una lámpara colgante con una jaula de metal en casa',
            'Probar a hacer una lámpara de techo con frascos de cristal en casa',
            'Hacer una lámpara de pared con tubos de PVC en casa',
            'Probar a hacer una lámpara de mesa con figuras geométricas en casa',
            'Hacer una lámpara colgante con madera flotante en casa',
            'Probar a hacer una lámpara de pie con bombillas LED en casa',
            'Hacer una lámpara de mesa con elementos reciclados en casa',
            'Probar a hacer una lámpara de pared con materiales naturales en casa'
        ]
    },
    'Aprendizaje en Línea': {
        'Idiomas': [
            'Practicar conjugación de verbos en francés con una aplicación en casa',
            'Tomar una clase de conversación en inglés en {plataforma}',
            'Hacer ejercicios de vocabulario en alemán usando una app en casa',
            'Probar un curso de chino mandarín para principiantes en casa',
            'Realizar un examen de nivel de español en {plataforma}',
            'Practicar pronunciación en italiano con un profesor en línea desde casa',
            'Tomar una clase de gramática avanzada en portugués en {plataforma}',
            'Hacer ejercicios de escritura en japonés usando una app en casa',
            'Probar un curso de conversación en ruso en casa',
            'Tomar una clase de gramática en inglés enfocada en tiempos verbales en {plataforma}',
            'Hacer ejercicios de pronunciación en francés con una aplicación en casa',
            'Practicar vocabulario de alemán con un juego en línea en {plataforma}',
            'Tomar una clase de idiomas en grupo en {plataforma}',
            'Hacer una clase de conversación de italiano con un tutor en línea desde casa',
            'Practicar escritura en chino utilizando un curso en línea en casa',
            'Probar un curso intensivo de ruso en {plataforma}',
            'Tomar una clase de comprensión auditiva en inglés en casa',
            'Hacer una clase de vocabulario en japonés con una app en casa',
            'Practicar la pronunciación en portugués con un profesor en línea en {plataforma}',
            'Tomar una clase de español avanzado en casa'
        ],
        'Fotografía': [
            'Tomar un curso de fotografía básica en {plataforma}',
            'Probar una clase de edición de fotos con {software} en casa',
            'Hacer un taller de fotografía de retrato en línea desde casa',
            'Aprender sobre fotografía nocturna en un curso en {plataforma}',
            'Tomar una clase de composición fotográfica en casa',
            'Probar un curso de fotografía con smartphone en casa',
            'Hacer una clase de fotografía macro con un tutorial en línea en {plataforma}',
            'Tomar un curso de fotografía de paisajes desde casa',
            'Aprender sobre iluminación fotográfica en {plataforma}',
            'Probar un curso de retoque fotográfico en línea en casa',
            'Hacer una clase de fotografía urbana con un taller en casa',
            'Tomar un curso de fotografía analógica en {plataforma}',
            'Aprender a utilizar una cámara réflex digital en línea desde casa',
            'Probar una clase de edición de fotos con Lightroom en {plataforma}',
            'Hacer una clase de fotografía de productos en línea desde casa',
            'Aprender sobre fotografía de moda en un curso en {plataforma}',
            'Probar un taller de fotografía documental en casa',
            'Tomar un curso de fotografía creativa en casa',
            'Hacer una clase de fotografía en blanco y negro en {plataforma}',
            'Aprender técnicas de fotografía callejera en casa'
        ],
        'Programación': [
            'Tomar un curso de Python para principiantes en {plataforma}',
            'Hacer ejercicios de programación en JavaScript desde casa',
            'Probar un curso de desarrollo web con HTML y CSS en {plataforma}',
            'Tomar una clase de SQL y bases de datos en casa',
            'Hacer un curso de programación en C++ para intermedios en {plataforma}',
            'Probar una clase de desarrollo de aplicaciones móviles en casa',
            'Tomar un curso de inteligencia artificial y machine learning en {plataforma}',
            'Hacer ejercicios de programación en R desde casa',
            'Probar un curso de desarrollo de videojuegos en Unity en casa',
            'Tomar una clase de programación en Java en casa',
            'Hacer un taller de desarrollo web full-stack en {plataforma}',
            'Probar un curso de creación de APIs en línea desde casa',
            'Tomar una clase de programación en Swift para iOS en casa',
            'Hacer ejercicios de algoritmos y estructuras de datos en {plataforma}',
            'Probar un curso de desarrollo de software en línea en casa',
            'Tomar una clase de desarrollo de bases de datos en SQL en {plataforma}',
            'Hacer un curso de programación de Python avanzado desde casa',
            'Probar una clase de desarrollo de aplicaciones web con React en {plataforma}',
            'Tomar un taller de desarrollo de videojuegos en casa',
            'Hacer ejercicios de lógica de programación en línea en casa'
        ],
        'Historia': [
            'Tomar un curso de historia de la antigua Roma en {plataforma}',
            'Probar una clase de historia del arte renacentista en casa',
            'Hacer un curso de historia de la Segunda Guerra Mundial en {plataforma}',
            'Tomar una clase de historia contemporánea en casa',
            'Hacer un curso sobre las civilizaciones antiguas en {plataforma}',
            'Probar una clase de historia medieval europea en casa',
            'Tomar un curso de historia de la América precolombina en {plataforma}',
            'Hacer un taller de historia de la Revolución Industrial desde casa',
            'Probar un curso de historia de las mujeres en línea en casa',
            'Tomar una clase de historia del Imperio Otomano en {plataforma}',
            'Hacer un curso de historia de la Guerra Fría en línea en casa',
            'Probar una clase sobre la historia de las religiones en {plataforma}',
            'Tomar un taller de historia de las migraciones humanas en casa',
            'Hacer un curso de historia de la Edad Media en casa',
            'Probar una clase de historia de las grandes revoluciones en línea en {plataforma}',
            'Tomar un curso de historia del arte contemporáneo en casa',
            'Hacer un taller de historia de las civilizaciones mesoamericanas en casa',
            'Probar un curso de historia de los imperios europeos en línea en {plataforma}',
            'Tomar una clase de historia de la música clásica en casa',
            'Hacer un curso de historia de los descubrimientos geográficos en casa'
        ],
        'Marketing Digital': [
            'Tomar un curso de SEO y optimización web en {plataforma}',
            'Hacer un taller de publicidad en redes sociales desde casa',
            'Probar un curso de email marketing en {plataforma}',
            'Tomar una clase de análisis de datos de marketing en casa',
            'Hacer un curso de marketing de contenidos en {plataforma}',
            'Probar una clase de estrategia de marketing en casa',
            'Tomar un curso de marketing en redes sociales en {plataforma}',
            'Hacer ejercicios prácticos de Google Ads en casa',
            'Probar un curso de marketing de influencia en línea en casa',
            'Tomar una clase de marketing digital para principiantes en {plataforma}',
            'Hacer un taller de optimización de campañas publicitarias en casa',
            'Probar un curso de analítica web con Google Analytics en {plataforma}',
            'Tomar una clase de estrategias de branding en línea en casa',
            'Hacer un curso de publicidad en Facebook Ads en casa',
            'Probar un taller de marketing móvil en {plataforma}',
            'Tomar un curso de marketing basado en datos en casa',
            'Hacer una clase de gestión de redes sociales en casa',
            'Probar un curso de creación de embudos de ventas en {plataforma}',
            'Tomar una clase de growth hacking en línea desde casa',
            'Hacer un taller de marketing por afiliación en casa'
        ],
        'Cocina': [
            'Tomar un curso de cocina italiana en {plataforma}',
            'Probar una clase de repostería en línea desde casa',
            'Hacer un taller de cocina vegana en {plataforma}',
            'Tomar una clase de cocina asiática en casa',
            'Hacer un curso de panadería artesanal en {plataforma}',
            'Probar una clase de cocina saludable en casa',
            'Tomar un curso de cocina francesa en línea en {plataforma}',
            'Hacer una clase de cocina de platos rápidos en casa',
            'Probar un taller de cocina mediterránea en línea en casa',
            'Tomar una clase de cocina mexicana en {plataforma}',
            'Hacer un curso de cocina para principiantes en casa',
            'Probar una clase de pastelería con tutoriales en línea en {plataforma}',
            'Tomar un curso de cocina de comida rápida saludable en casa',
            'Hacer una clase de cocina india con especias en casa',
            'Probar un taller de cocina de platos sin gluten en {plataforma}',
            'Tomar un curso de cocina molecular en casa',
            'Hacer una clase de cocina casera con productos de temporada en casa',
            'Probar un curso de cocina internacional en {plataforma}',
            'Tomar una clase de postres creativos en casa',
            'Hacer un taller de cocina tradicional española en casa'
        ],
        'Jardinería': [
            'Tomar un curso de jardinería básica en {plataforma}',
            'Probar una clase de cultivo de huertos en casa desde casa',
            'Hacer un taller de plantas aromáticas en línea en {plataforma}',
            'Tomar una clase de cuidado de plantas de interior en casa',
            'Hacer un curso de jardinería orgánica en {plataforma}',
            'Probar una clase de cultivo de suculentas en casa',
            'Tomar un curso de diseño de jardines en {plataforma}',
            'Hacer una clase de poda de árboles frutales en casa',
            'Probar un taller de cultivo de bonsáis en casa',
            'Tomar una clase de jardinería en terrazas en {plataforma}',
            'Hacer un curso de plantas medicinales en línea en casa',
            'Probar una clase de diseño de jardines verticales en {plataforma}',
            'Tomar un taller de jardinería urbana en casa',
            'Hacer una clase de cuidado de cactus en casa',
            'Probar un curso de compostaje en {plataforma}',
            'Tomar una clase de huertos en macetas en casa',
            'Hacer un curso de paisajismo para principiantes en casa',
            'Probar una clase de plantas tropicales en línea en {plataforma}',
            'Tomar una clase de control de plagas en jardines en casa',
            'Hacer un taller de jardinería en balcones en casa'
        ],
        'Desarrollo Personal': [
            'Tomar un curso de mindfulness para reducir el estrés en {plataforma}',
            'Hacer una clase de gestión del tiempo en línea desde casa',
            'Probar un curso de inteligencia emocional en {plataforma}',
            'Tomar una clase de técnicas de relajación en casa',
            'Hacer un curso de liderazgo personal en {plataforma}',
            'Probar una clase de autoayuda para mejorar la autoestima en casa',
            'Tomar un curso de desarrollo de habilidades de comunicación en {plataforma}',
            'Hacer ejercicios de meditación guiada en casa',
            'Probar un curso de motivación personal en línea en casa',
            'Tomar una clase de organización y productividad en {plataforma}',
            'Hacer un curso de autoconocimiento para el desarrollo personal en casa',
            'Probar una clase de hábitos saludables en línea en {plataforma}',
            'Tomar una clase de mindfulness para principiantes en casa',
            'Hacer un curso de resolución de conflictos en casa',
            'Probar un taller de superación de miedos en línea en {plataforma}',
            'Tomar una clase de coaching personal para alcanzar metas en casa',
            'Hacer un curso de gestión del cambio en casa',
            'Probar una clase de bienestar emocional en línea en {plataforma}',
            'Tomar un taller de autoconfianza en casa',
            'Hacer ejercicios de visualización para alcanzar objetivos en casa'
        ],
        'Diseño Gráfico': [
            'Tomar un curso de Adobe Photoshop para principiantes en {plataforma}',
            'Hacer una clase de diseño de logotipos en línea desde casa',
            'Probar un curso de diseño gráfico con Illustrator en {plataforma}',
            'Tomar una clase de tipografía y diseño en casa',
            'Hacer un curso de diseño de interfaces de usuario en {plataforma}',
            'Probar una clase de branding y diseño de identidad en casa',
            'Tomar un curso de diseño de packaging en {plataforma}',
            'Hacer ejercicios prácticos de diseño web en casa',
            'Probar un curso de creación de banners publicitarios en línea en casa',
            'Tomar una clase de diseño gráfico avanzado en {plataforma}',
            'Hacer un taller de diseño editorial en casa',
            'Probar una clase de ilustración digital en línea en {plataforma}',
            'Tomar un curso de diseño de infografías en casa',
            'Hacer una clase de diseño de aplicaciones móviles en casa',
            'Probar un curso de animación gráfica en {plataforma}',
            'Tomar una clase de diseño de contenido para redes sociales en casa',
            'Hacer un curso de diseño gráfico para marcas en casa',
            'Probar una clase de creatividad en diseño gráfico en {plataforma}',
            'Tomar un taller de diseño con Figma en casa',
            'Hacer ejercicios de diseño gráfico con Canva en casa'
        ],
        'Música': [
            'Tomar un curso de teoría musical básica en {plataforma}',
            'Hacer una clase de guitarra para principiantes en línea desde casa',
            'Probar un curso de producción musical con software en {plataforma}',
            'Tomar una clase de canto y técnica vocal en casa',
            'Hacer un curso de piano para principiantes en {plataforma}',
            'Probar una clase de composición musical en casa',
            'Tomar un curso de edición de audio con {software} en {plataforma}',
            'Hacer ejercicios de improvisación musical en casa',
            'Probar un curso de grabación casera en línea en casa',
            'Tomar una clase de mezcla y masterización en {plataforma}',
            'Hacer un curso de teoría musical avanzada en casa',
            'Probar una clase de producción de música electrónica en línea en {plataforma}',
            'Tomar un curso de canto coral en casa',
            'Hacer una clase de composición de bandas sonoras en casa',
            'Probar un curso de música clásica en {plataforma}',
            'Tomar una clase de producción de música urbana en casa',
            'Hacer un taller de dirección musical en casa',
            'Probar un curso de guitarra eléctrica en línea en {plataforma}',
            'Tomar una clase de solfeo para mejorar la lectura de partituras en casa',
            'Hacer un curso de improvisación de jazz en casa'
        ]
    }
    }

# Datos para rellenar las plantillas
template_data = {
    'tema': ['paisajes', 'animales', 'retratos', 'naturaleza muerta', 'abstracción', 'fantasía', 'ciudad', 'mar', 'montañas', 'flores'],
    'persona': ['un familiar', 'un amigo', 'un personaje famoso', 'uno mismo', 'una mascota', 'un desconocido', 'un niño', 'un anciano', 'un deportista', 'un artista'],
    'objeto': ['una manzana', 'una taza', 'un libro', 'un instrumento musical', 'un zapato', 'una flor', 'un vehículo', 'un edificio', 'un juguete', 'un árbol'],
    'estilo': ['realista', 'abstracto', 'impresionista', 'surrealista', 'minimalista', 'cubista', 'pop art', 'expresionista', 'arte callejero', 'modernista'],
    'tecnica': ['acuarela', 'óleo', 'acrílico', 'carboncillo', 'tinta', 'pastel', 'lápiz', 'collage', 'grabado', 'aerografía'],
    'material': ['lana', 'algodón', 'seda', 'hilo acrílico', 'trapillo', 'cuero', 'lino', 'fieltro', 'hilo de metal', 'cuerda'],
    'materiales': ['cuentas', 'alambre', 'piedras', 'cristales', 'arcilla polimérica', 'plástico reciclado', 'resina', 'hilo', 'cintas', 'plumas'],
    'aroma': ['lavanda', 'vainilla', 'cítricos', 'rosa', 'canela', 'madera', 'eucalipto', 'jazmín', 'menta', 'coco'],
    'ingredientes': ['aceite de oliva', 'miel', 'avena', 'aloe vera', 'leche de coco', 'esencias naturales', 'arcilla', 'café', 'azúcar', 'sal marina'],
    'sabor': ['chocolate', 'vainilla', 'fresa', 'limón', 'zanahoria', 'manzana', 'red velvet', 'coco', 'plátano', 'calabaza'],
    'extra': ['nueces', 'chispas de chocolate', 'caramelo', 'frutos rojos', 'pasas', 'almendras', 'avellanas', 'arándanos', 'coco rallado', 'merengue'],
    'tipo': ['blanco', 'integral', 'de centeno', 'multicereal', 'de espelta', 'sin gluten', 'con semillas', 'de masa madre', 'brioche', 'de molde'],
    'superficie': ['lienzo', 'pared', 'papel', 'madera', 'cartón', 'tela', 'vidrio', 'cerámica', 'metal', 'plástico'],
    'proyecto': ['empresa ficticia', 'proyecto personal', 'amigo', 'familia', 'mascota', 'causa benéfica', 'evento local', 'marca de ropa', 'banda musical', 'sitio web'],
    'objetivo': ['relajación', 'flexibilidad', 'fuerza', 'equilibrio', 'energía', 'concentración', 'bienestar', 'postura', 'respiración', 'meditación'],
    'postura': ['saludo al sol', 'perro boca abajo', 'guerrero', 'árbol', 'triángulo', 'cobra', 'puente', 'equilibrio', 'torsión', 'paloma'],
    'accesorio': ['bloques', 'cinta', 'silla', 'pared', 'columpio de yoga', 'bandas elásticas', 'rueda de yoga', 'cojín de meditación', 'toalla'],
    'etapa': ['primer trimestre', 'segundo trimestre', 'tercer trimestre'],
    'dolor': ['espalda', 'cuello', 'hombros', 'rodillas', 'caderas', 'cabeza', 'pies', 'manos', 'articulaciones', 'tensión muscular'],
    'figura': ['grulla', 'flor', 'dragón', 'caja', 'estrella', 'mariposa', 'corazón', 'pájaro', 'barco', 'avión'],
    'diseno': ['floral', 'geométrico', 'abstracto', 'animal', 'paisaje', 'minimalista', 'vintage', 'moderno', 'infantil', 'tipográfico'],
    'relleno': ['pollo', 'carne', 'verduras', 'pescado', 'mariscos', 'queso', 'frijoles', 'tofu', 'setas', 'huevo'],
    'variacion': ['picante', 'con pimentón', 'de remolacha', 'de aguacate', 'con cilantro', 'de zanahoria', 'con ajo asado', 'de edamame', 'con chile', 'de lentejas'],
    'proteina': ['pollo', 'cerdo', 'ternera', 'tofu', 'gambas', 'pato', 'huevo', 'seitán', 'tempeh', 'vegetales'],
    'salsa': ['chocolate', 'caramelo', 'fresa', 'dulce de leche', 'vainilla', 'crema', 'miel', 'maple', 'frutos rojos', 'limón'],
    'topping': ['frutas', 'sirope', 'nueces', 'chocolate', 'mermelada', 'nata montada', 'galletas', 'granola', 'miel', 'coco rallado'],
    'ingrediente': ['mariscos', 'pollo', 'conejo', 'verduras', 'mixta', 'vegetariana', 'setas', 'chorizo', 'arroz negro', 'bogavante'],
    'tipo': ['rojo', 'verde', 'amarillo', 'massaman', 'panang', 'korma', 'vindaloo', 'tikka masala', 'jalfrezi', 'madras'],
    'salsa': ['boloñesa', 'carbonara', 'pesto', 'alfredo', 'arrabiata', 'puttanesca', 'napolitana', 'cuatro quesos', 'marinara', 'funghi'],
    'ingredientes': ['cerdo', 'pollo', 'ternera', 'vegetales', 'mariscos', 'tofu', 'miso', 'huevo', 'algas', 'fideos soba'],
    'herramienta': ['esponja', 'espátula', 'aerógrafo', 'rodillo', 'plumilla', 'pincel de abanico', 'lápiz de colores', 'pastel al óleo', 'spray', 'esténcil'],
    'aventura': ['superhéroes', 'viajes en el tiempo', 'espacio', 'fantasía medieval', 'animales parlantes', 'misterios', 'piratas', 'zombis', 'robots', 'magia'],
    'persona': ['pareja', 'amigo', 'familiar', 'hijo', 'compañero de trabajo', 'vecino', 'hermano', 'mascota', 'padre', 'madre'],
    'plataforma': ['Coursera', 'edX', 'Udemy', 'Platzi', 'Domestika', 'Khan Academy', 'FutureLearn', 'LinkedIn Learning', 'Skillshare', 'YouTube'],
    'habilidad': ['fotografía', 'dibujo', 'escritura creativa', 'negocios', 'marketing digital', 'idiomas', 'cocina', 'programación', 'música', 'diseño gráfico'],
    'tema': ['historia', 'ciencia', 'arte', 'música', 'literatura', 'cine', 'deportes', 'geografía', 'cultura general', 'tecnología'],
    'idioma': ['inglés', 'francés', 'alemán', 'japonés', 'italiano', 'chino', 'portugués', 'ruso', 'árabe', 'coreano'],
    'lenguaje': ['Python', 'JavaScript', 'Java', 'C++', 'Ruby', 'Swift', 'PHP', 'C#', 'Go', 'R'],
    'campo': ['datos', 'gestión de proyectos', 'ciberseguridad', 'inteligencia artificial', 'finanzas', 'diseño UX/UI', 'marketing', 'redes', 'análisis de negocios', 'enseñanza'],
    'canción': ['favorita', 'popular', 'clásica', 'moderna', 'de película', 'de anime', 'de videojuegos', 'romántica', 'instrumental', 'de rock'],
    'estilo': ['salsa', 'bachata', 'tango', 'hip-hop', 'jazz', 'contemporáneo', 'clásico', 'flamenco', 'bollywood', 'folclórico'],
    'intensidad': ['suave', 'moderada', 'intensa'],
    'dispositivo': ['guitarra', 'piano', 'violín', 'batería', 'flauta', 'saxofón', 'ukelele', 'armónica', 'bajo', 'cello'],
    'proyecto': ['jardín interior', 'decoración del hogar', 'organización de armario', 'mejora de hábitos', 'rutina de ejercicios', 'dieta saludable', 'plan de ahorro', 'aprendizaje de idioma', 'lectura mensual', 'planificación de viaje'],
    'materiales': ['palets', 'botellas recicladas', 'latas', 'madera', 'papel', 'vidrio', 'plástico', 'tela', 'metal', 'cartón'],
    'herramientas': ['martillo', 'destornillador', 'taladro', 'lijadora', 'sierra', 'cúter', 'pistola de pegamento', 'brocha', 'regla', 'nivel'],
    'actividad': ['maratón de películas', 'juegos de mesa', 'karaoke', 'fiesta temática', 'taller de manualidades', 'sesión de fotos', 'torneo de videojuegos', 'cata de vinos', 'noche de trivia', 'clase de cocina'],
    'evento': ['cumpleaños', 'boda', 'graduación', 'aniversario', 'baby shower', 'navidad', 'año nuevo', 'halloween', 'día de san valentín', 'fiesta sorpresa'],
    'juego': ['ajedrez', 'monopoly', 'cartas', 'scrabble', 'risk', 'cluedo', 'catán', 'pictionary', 'trivial pursuit', 'uno'],
    'piezas': ['500', '1000', '1500', '2000', '3000', '4000', '5000', '6000', '7000', '8000'],
    'nivel': ['fácil', 'medio', 'difícil', 'experto'],
    'director': ['Alfred Hitchcock', 'Steven Spielberg', 'Martin Scorsese', 'Quentin Tarantino', 'Christopher Nolan', 'Stanley Kubrick', 'Ridley Scott', 'Tim Burton', 'Guillermo del Toro', 'Pedro Almodóvar'],
    'premio': ['Oscar', 'Cannes', 'Sundance', 'BAFTA', 'Globos de Oro', 'Emmy', 'Grammy', 'Goya', 'Palma de Oro', 'León de Oro'],
    'lugar':['París', 'Nueva York', 'Roma', 'Tokio', 'Londres', 'Barcelona', 'Sídney', 'Río de Janeiro', 'Moscú', 'El Cairo'],
    'edificio': ['Torre Eiffel', 'Empire State', 'Coliseo', 'Tokyo Tower', 'Big Ben', 'Sagrada Familia', 'Opera House', 'Cristo Redentor', 'Kremlin', 'Pirámides de Giza'],
    'época': ['antigua', 'medieval', 'renacentista', 'barroca', 'victoriana', 'moderna', 'contemporánea', 'futurista', 'post-apocalíptica', 'alternativa'],
    'artista': ['Beyoncé', 'Michael Jackson', 'Madonna', 'Elvis Presley', 'The Beatles', 'Bob Marley', 'Prince', 'Whitney Houston', 'David Bowie', 'Queen'],
    'beneficio': ['relajación', 'concentración', 'creatividad', 'autoestima', 'bienestar', 'salud mental', 'autoconocimiento', 'motivación', 'inspiración', 'diversión'],
    'software': ['Photoshop', 'Illustrator', 'InDesign', 'Lightroom', 'Premiere', 'After Effects', 'Audition', 'Animate', 'Dreamweaver', 'XD'],
    'autor': ['Shakespeare', 'Cervantes', 'García Márquez', 'Borges', 'Neruda', 'Poe', 'Tolkien', 'Dickens', 'Dostoievski', 'Austen'],
    'década': ['20s', '30s', '40s', '50s', '60s', '70s', '80s', '90s', '2000s', '2010s'],
    'país': ['Francia', 'Italia', 'España', 'México', 'Japón', 'India', 'China', 'Rusia', 'Brasil', 'Australia'],
    'ciudad': ['París', 'Roma', 'Barcelona', 'Nueva York', 'Tokio', 'Londres', 'Berlín', 'Sídney', 'Río de Janeiro', 'Moscú'],
    'pescado': ['salmón', 'atún', 'bacalao', 'merluza', 'lubina', 'dorada', 'sardinas', 'boquerones'],
    'fruta': ['mango', 'papaya', 'piña', 'guayaba', 'maracuyá', 'carambola', 'pitahaya', 'kiwi'],
    'parte del cuerpo': ['cabeza', 'cuello', 'hombros', 'espalda', 'brazos', 'codos', 'muñecas', 'manos', 'dedos', 'cintura'],
    
}

def generate_unique_activities(n_activities):
    activities = []
    used_names = set()

    # Generar todas las combinaciones posibles de categoría y subcategoría
    all_combinations = []
    for category in category_templates:
        for subcategory in category_templates[category]:
            all_combinations.append((category, subcategory))

    while len(activities) < n_activities:
        # Seleccionar una combinación aleatoria
        category, subcategory = random.choice(all_combinations)

        # Seleccionar una plantilla aleatoria
        template = random.choice(category_templates[category][subcategory])

        # Rellenar la plantilla
        activity_name = template
        for key in template_data:
            if '{' + key + '}' in activity_name:
                activity_name = activity_name.replace('{' + key + '}', random.choice(template_data[key]))

        # Verificar si el nombre es único
        if activity_name not in used_names:
            used_names.add(activity_name)

            activities.append({
                'ID': len(activities) + 1,
                'Nombre_Tarea': activity_name,
                'Categoria_Principal': category,
                'Subcategoria': subcategory,
                'Indoor_Outdoor': 'Indoor',
                'Tiempo_Estimado_Minutos': random.choice([15, 30, 45, 60, 90, 120]),
                'Requiere_Ubicacion': False,
                'API_Categoria': None,
                'Descripcion': f"Disfruta de {activity_name} en casa dentro de la categoría de {category}"
            })

    return activities

# Generar actividades en bloques de 200
all_activities = []
for _ in range(50):
    activities = generate_unique_activities(200)
    df_temp = pd.DataFrame(activities)

    # Eliminar duplicados
    df_temp = df_temp.drop_duplicates(subset='Nombre_Tarea')

    all_activities.append(df_temp)

# Combinar todas las actividades
df_final = pd.concat(all_activities).drop_duplicates(subset='Nombre_Tarea').reset_index(drop=True)

# Guardar en CSV
df_final.to_csv('data/cleaned/home_activities.csv', index=False)

# Mostrar estadísticas básicas
print("\nDistribución de categorías principales:")
print(df_final['Categoria_Principal'].value_counts())
print("\nEjemplos de actividades generadas:")
print(df_final[['Categoria_Principal', 'Subcategoria', 'Nombre_Tarea']].head(10))
# Out:
# Distribución de categorías principales:
# Categoria_Principal
# Aprendizaje en Línea                436
# Cocina                              328
# Juegos de Mesa y Entretenimiento    320
# Lectura y Escritura Creativa        304
# Ejercicio y Fitness en Casa         295
# Manualidades                        290
# Música y Baile                      246
# Cuidado Personal y Relajación       200
# Jardinería Interior                 200
# Proyectos DIY (Hazlo Tú Mismo)      198
# Name: count, dtype: int64
#
# Ejemplos de actividades generadas:
#               Categoria_Principal              Subcategoria  \
# 0            Aprendizaje en Línea                  Historia
# 1   Cuidado Personal y Relajación    Terapias de Relajación
# 2  Proyectos DIY (Hazlo Tú Mismo)  Manualidades Funcionales
# 3                  Música y Baile          Ritmos del Mundo
# 4                  Música y Baile                     Canto
# 5             Jardinería Interior                 Terrarios
# ...

# %% [markdown]
# ## Outdoor activities

# %%
import pandas as pd
import random

# Definir estructura de categorías y subcategorías con sus plantillas para actividades al aire libre
category_templates = {
    'Deportes al Aire Libre': {
        'Running': [
            'Correr {distancia} km en {lugar}',
            'Hacer entrenamiento de intervalos en {lugar}',
            'Participar en una carrera local de {distancia} km',
            'Correr por senderos naturales en {lugar}',
            'Hacer un entrenamiento de cuestas en {lugar}',
            'Participar en un maratón urbano',
            'Correr con un grupo de running en {lugar}',
            'Hacer sprints en {lugar}',
            'Entrenar para una media maratón en {lugar}',
            'Correr al amanecer por {lugar}'
        ],
        'Ciclismo': [
            'Hacer una ruta en bicicleta por {lugar}',
            'Participar en una excursión ciclista de {distancia} km',
            'Explorar senderos en mountain bike por {lugar}',
            'Hacer ciclismo de carretera en {ruta}',
            'Participar en un evento ciclista local',
            'Hacer una ruta de cicloturismo por {lugar}',
            'Explorar rutas ciclistas urbanas',
            'Hacer descenso en bicicleta en {lugar}',
            'Participar en una carrera de ciclismo de montaña',
            'Hacer una ruta panorámica en bicicleta por {lugar}'
        ],
        'Senderismo': [
            'Hacer una caminata por {lugar}',
            'Explorar un sendero nuevo en {lugar}',
            'Hacer trekking de {dificultad} en {lugar}',
            'Participar en una excursión guiada por {lugar}',
            'Hacer una ruta de senderismo con observación de aves',
            'Explorar un parque natural cercano',
            'Hacer una caminata nocturna con luna llena',
            'Participar en una ruta interpretativa por {lugar}',
            'Hacer una excursión fotográfica por {lugar}',
            'Explorar senderos históricos en {lugar}'
        ],
        'Escalada': [
            'Practicar boulder en {lugar}',
            'Hacer escalada deportiva en {lugar}',
            'Participar en una sesión de escalada guiada',
            'Hacer escalada en roca natural en {lugar}',
            'Practicar técnicas de escalada en {lugar}',
            'Hacer una ruta de varios largos en {lugar}',
            'Participar en un curso de iniciación a la escalada',
            'Hacer escalada tradicional en {lugar}',
            'Practicar técnicas de aseguramiento en {lugar}',
            'Hacer una sesión de escalada con amigos'
        ]
    },
    'Actividades Acuáticas': {
        'Natación': [
            'Nadar en aguas abiertas en {lugar}',
            'Hacer entrenamiento de natación en {lugar}',
            'Participar en un evento de natación al aire libre',
            'Hacer snorkel en {lugar}',
            'Practicar técnicas de natación en {lugar}',
            'Hacer una travesía a nado en {lugar}',
            'Participar en una competición de aguas abiertas',
            'Hacer ejercicios de natación en {lugar}',
            'Practicar natación de larga distancia en {lugar}',
            'Hacer una sesión de natación recreativa'
        ],
        'Surf': [
            'Tomar una clase de surf en {playa}',
            'Practicar surf en {playa}',
            'Hacer bodyboard en {playa}',
            'Participar en una sesión de surf guiada',
            'Practicar técnicas de surf en {playa}',
            'Hacer paddle surf en {lugar}',
            'Tomar una clase de longboard en {playa}',
            'Practicar maniobras de surf en {playa}',
            'Hacer surf al atardecer en {playa}',
            'Participar en una competición local de surf'
        ],
        'Kayak': [
            'Hacer kayak en {lugar}',
            'Participar en una excursión en kayak por {lugar}',
            'Hacer kayak de mar en {lugar}',
            'Practicar técnicas de kayak en {lugar}',
            'Hacer una ruta en kayak por {río}',
            'Participar en un curso de kayak',
            'Hacer kayak de aguas bravas en {río}',
            'Explorar la costa en kayak',
            'Hacer una excursión nocturna en kayak',
            'Practicar eskimotaje en kayak'
        ]
    },
    'Deportes de Equipo': {
        'Fútbol': [
            'Jugar un partido de fútbol en {lugar}',
            'Participar en un torneo local de fútbol',
            'Organizar un partido amistoso en {lugar}',
            'Hacer entrenamiento de fútbol en {lugar}',
            'Jugar fútbol 5 al aire libre',
            'Participar en una liga amateur de fútbol',
            'Hacer ejercicios técnicos de fútbol en {lugar}',
            'Organizar un torneo de fútbol con amigos',
            'Jugar fútbol playa en {lugar}',
            'Participar en un entrenamiento de fútbol grupal'
        ],
        'Voleibol': [
            'Jugar voleibol playa en {lugar}',
            'Participar en un torneo de voleibol al aire libre',
            'Organizar un partido de voleibol en {lugar}',
            'Hacer entrenamiento de voleibol en {lugar}',
            'Jugar voleibol con amigos al aire libre',
            'Participar en una liga de voleibol playa',
            'Hacer ejercicios técnicos de voleibol en {lugar}',
            'Organizar un torneo de voleibol playa',
            'Jugar voleibol mixto al aire libre',
            'Participar en clases de voleibol'
        ],
        'Baloncesto': [
            'Jugar baloncesto en {lugar}',
            'Participar en un torneo de streetball',
            'Organizar un partido de baloncesto 3x3',
            'Hacer entrenamiento de baloncesto en {lugar}',
            'Jugar baloncesto con amigos al aire libre',
            'Participar en una liga local de baloncesto',
            'Hacer ejercicios de tiro en {lugar}',
            'Organizar un torneo de baloncesto callejero',
            'Jugar partidos informales de baloncesto',
            'Participar en entrenamientos grupales'
        ]
    },
    'Aventura y Exploración': {
        'Campamento': [
            'Acampar en {lugar}',
            'Hacer una acampada de fin de semana en {lugar}',
            'Participar en un campamento de aventura',
            'Hacer camping salvaje en {lugar}',
            'Organizar una acampada con amigos',
            'Hacer camping en {parque natural}',
            'Participar en un campamento de supervivencia',
            'Hacer una acampada familiar en {lugar}',
            'Organizar un campamento temático',
            'Hacer camping junto al {lugar}'
        ],
        'Geocaching': [
            'Buscar tesoros de geocaching en {lugar}',
            'Participar en un evento de geocaching',
            'Explorar nuevas ubicaciones de geocaching',
            'Hacer una ruta de geocaching por {lugar}',
            'Organizar una búsqueda del tesoro con GPS',
            'Participar en un multi-cache en {lugar}',
            'Hacer geocaching urbano',
            'Explorar caches misteriosos en {lugar}',
            'Participar en un evento CITO de geocaching',
            'Hacer geocaching nocturno'
        ],
        'Exploración Urbana': [
            'Explorar ruinas abandonadas en {lugar}',
            'Hacer una ruta fotográfica urbana',
            'Participar en una visita guiada histórica',
            'Explorar barrios antiguos de {ciudad}',
            'Hacer una ruta de arte urbano',
            'Participar en una búsqueda del tesoro urbana',
            'Explorar lugares secretos de {ciudad}',
            'Hacer una ruta arquitectónica',
            'Participar en una excursión histórica',
            'Explorar túneles antiguos'
        ]
    },
    'Jardinería y Agricultura': {
        'Huerto Urbano': [
            'Trabajar en el huerto comunitario de {lugar}',
            'Participar en un taller de agricultura urbana',
            'Cultivar verduras de temporada en {lugar}',
            'Hacer mantenimiento del huerto en {lugar}',
            'Organizar una jornada de siembra comunitaria',
            'Participar en un intercambio de semillas',
            'Hacer compostaje en el huerto comunitario',
            'Organizar un taller de agricultura ecológica',
            'Cultivar plantas aromáticas en {lugar}',
            'Participar en la cosecha comunitaria'
        ],
        'Jardinería Comunitaria': [
            'Participar en el mantenimiento de jardines públicos',
            'Hacer voluntariado en jardinería en {lugar}',
            'Plantar árboles en {lugar}',
            'Mantener un jardín comunitario en {lugar}',
            'Organizar una jornada de limpieza de jardines',
            'Participar en un proyecto de reforestación',
            'Hacer mantenimiento de parques públicos',
            'Organizar un taller de jardinería',
            'Crear un jardín de mariposas en {lugar}',
            'Participar en la poda de árboles urbanos'
        ]
    },
    'Arte al Aire Libre': {
        'Pintura': [
            'Pintar paisajes al aire libre en {lugar}',
            'Participar en una sesión de pintura en {lugar}',
            'Hacer acuarelas en la naturaleza',
            'Pintar escenas urbanas en {lugar}',
            'Organizar un taller de pintura al aire libre',
            'Participar en un evento de arte callejero',
            'Hacer bocetos de naturaleza en {lugar}',
            'Organizar una exposición al aire libre',
            'Pintar junto al {lugar}',
            'Participar en un concurso de pintura rápida'
        ],
        'Fotografía': [
            'Hacer una sesión fotográfica en {lugar}',
            'Participar en un safari fotográfico',
            'Fotografiar {tema} en {lugar}',
            'Hacer fotos nocturnas en {lugar}',
            'Organizar una caminata fotográfica',
            'Participar en un taller de fotografía al aire libre',
            'Hacer fotos de naturaleza en {lugar}',
            'Organizar una exposición fotográfica callejera',
            'Fotografiar el amanecer en {lugar}',
            'Participar en un reto fotográfico'
        ]
    }
}

# Datos para rellenar las plantillas
template_data = {
    'lugar': ['el parque local', 'la montaña', 'el bosque', 'la playa', 'el lago', 'la reserva natural', 
              'el centro histórico', 'el jardín botánico', 'la sierra', 'el valle'],
    'distancia': ['5', '10', '15', '20', '25', '30', '42'],
    'playa': ['la playa local', 'la costa salvaje', 'la cala escondida', 'la playa urbana', 
              'la playa norte', 'la playa sur', 'la playa del faro'],
    'río': ['el río local', 'el río de montaña', 'el río tranquilo', 'el río salvaje', 
            'el río urbano', 'el canal'],
    'ruta': ['la costa', 'la montaña', 'el valle', 'el circuito urbano', 'la vía verde', 
             'la ruta panorámica', 'el camino histórico'],
    'dificultad': ['baja', 'media', 'alta', 'extrema'],
    'parque natural': ['el parque nacional', 'la reserva natural', 'el parque regional', 
                      'el área protegida', 'el parque forestal'],
    'ciudad': ['Madrid', 'Barcelona', 'Valencia', 'Sevilla', 'Bilbao', 'Málaga', 
               'Zaragoza', 'Valladolid', 'La Coruña', 'Granada'],
    'tema': ['arquitectura', 'naturaleza', 'vida urbana', 'deportes', 'eventos culturales', 
             'arte callejero', 'mercados', 'festivales']
}

def generate_unique_activities(n_activities):
    activities = []
    used_names = set()

    # Generar todas las combinaciones posibles de categoría y subcategoría
    all_combinations = []
    for category in category_templates:
        for subcategory in category_templates[category]:
            all_combinations.append((category, subcategory))

    while len(activities) < n_activities:
        # Seleccionar una combinación aleatoria
        category, subcategory = random.choice(all_combinations)

        # Seleccionar una plantilla aleatoria
        template = random.choice(category_templates[category][subcategory])

        # Rellenar la plantilla
        activity_name = template
        for key in template_data:
            if '{' + key + '}' in activity_name:
                activity_name = activity_name.replace('{' + key + '}', random.choice(template_data[key]))

        # Verificar si el nombre es único
        if activity_name not in used_names:
            used_names.add(activity_name)

            activities.append({
                'ID': len(activities) + 1,
                'Nombre_Tarea': activity_name,
                'Categoria_Principal': category,
                'Subcategoria': subcategory,
                'Indoor_Outdoor': 'Outdoor',
                'Tiempo_Estimado_Minutos': random.choice([30, 60, 90, 120, 180, 240]),
                'Requiere_Ubicacion': True,
                'API_Categoria': None,
                'Descripcion': f"Disfruta de {activity_name} al aire libre dentro de la categoría de {category}"
            })

    return activities

# Generar actividades en bloques de 200
all_activities = []
for _ in range(50):
    activities = generate_unique_activities(200)
    df_temp = pd.DataFrame(activities)

    # Eliminar duplicados
    df_temp = df_temp.drop_duplicates(subset='Nombre_Tarea')

    all_activities.append(df_temp)

# Combinar todas las actividades
df_final = pd.concat(all_activities).drop_duplicates(subset='Nombre_Tarea').reset_index(drop=True)

# Guardar en CSV
df_final.to_csv('data/cleaned/outdoor_activities.csv', index=False)

# Mostrar estadísticas básicas
print("\nDistribución de categorías principales:")
print(df_final['Categoria_Principal'].value_counts())
print("\nEjemplos de actividades generadas:")
print(df_final[['Categoria_Principal', 'Subcategoria', 'Nombre_Tarea']].head(10))
